# %% [markdown]
# # Vidio Sentiment Analyzer : Unveiling User Sentiments in Google Play Reviews

# %% [markdown]
# `Vidio Sentiment Analyzer: Mengungkap Sentimen Pengguna dalam Ulasan Google Play` merupakan pendekatan inovatif untuk mengidentifikasi pola-pola utama dalam kumpulan ulasan pengguna. Di era informasi digital yang berkembang pesat seperti sekarang, sangat penting bagi Vidio sebagai platform terkemuka untuk mengetahui dan memahami isu-isu utama yang diungkapkan oleh pengguna.
#
# `Sentiment Analyzer` menggunakan teknik canggih untuk memahami sentimen yang mendominasi dalam ulasan Google Play. Dengan volume feedback pengguna yang besar, menjadi sangat penting bagi Vidio untuk mendapatkan wawasan tentang sentimen pengguna.
#
# Penerapan analisis sentimen memungkinkan Vidio mengkategorikan ulasan pengguna menjadi sentimen positif dan negatif memungkinkan pemahaman yang lebih mendalam tentang pengalaman dan preferensi pengguna. Metrik evaluasi yang relevan dapat mencakup distribusi polaritas sentimen, intensitas sentimen, dan tren sentimen dari waktu ke waktu.
#
# Dalam konteks ini, metrik evaluasi kunci dapat melibatkan metrik-metrik standar analisis sentimen seperti akurasi, precision, recall, dan F1 Score. Metrik-metrik ini memberikan pandangan komprehensif tentang seberapa baik Sentiment Analyzer dalam mengklasifikasikan sentimen pengguna dengan akurat.
#
# Wawasan yang diperoleh dari Sentiment Analyzer dapat memberdayakan Vidio untuk meningkatkan kepuasan pengguna, memprioritaskan perbaikan fitur, dan menanggapi masalah dengan cepat. Dengan fokus pada sentimen pengguna, Vidio dapat secara strategis menyelaraskan upayanya untuk memenuhi harapan pengguna dan menjaga pengalaman pengguna yang positif.
#
# Melalui Vidio Sentiment Analyzer, Vidio dapat menavigasi lanskap dinamis opini pengguna di platform Google Play, memungkinkan pengambilan keputusan yang berbasis informasi dan langkah-langkah proaktif untuk meningkatkan kepuasan pengguna.

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Import Library

# %%
import pandas as pd
from datetime import datetime
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from gensim import corpora, models
import pyLDAvis.gensim_models as gensimvis
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.tokenize import word_tokenize
import pycrfsuite 
# Download data NLTK
nltk.download('stopwords')
nltk.download('wordnet')
import re
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.tag import CRFTagger
from nltk.stem import PorterStemmer
from collections import Counter
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from gensim.corpora.dictionary import Dictionary
from gensim.models import LdaMulticore
from gensim.models import LdaModel
from gensim.models.coherencemodel import CoherenceModel
from pprint import pprint

# import pickle and json file for columns and model file
import pickle
import json
import joblib
import yaml
import src.util as util
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
config_data = util.load_config()

# %% [markdown]
# ## Data Gathering

# %% [markdown]
# Data yang digunakan merupakan data yang diambil atau discrapping dari google play pada aplikasi Vidio mulai tanggal 2020-08-03 - 2023-12-20 sebanyak 10000 rows

# %%
#Import data yang sudah dibuat sebelumnya dari proses data preparation
data_preproc = util.pickle_load(config_data["data_preparation_result_path"][1])

# %%
# sanity check
data_preproc
# Out:
#                                                 content sentiment
# 5575  Sumpah aplikasi ini bikin gw kesel sendiri. Ud...   Negatif
# 8625  lumayan bagus tapi tolong di perbaiki gangguan...   Positif
# 9029  Bagus banget Jadi bisa lihat TV dimn pun saat ...   Positif
# 6474  Masa tidak bisa tampilkan semua liga, kami mau...   Negatif
# 6954  Kayaknya aplikasi OONA lebih bagus, bagi yg ke...   Negatif
# ...                                                 ...       ...
# 56    Aplikasi dari 2015 tapi film dan anime yang te...   Negatif
# 626   Saya menyesal berlanggan vidio karena pembayar...   Negatif
# 1851  tolong apknya di update dong masa gak ada film...   Negatif
# 59    masa nonton premier league vidionya lebih lamb...   Negatif
# 472      Kurang bagus aplikasinya, terlalu banyak iklan   Negatif
#
# [10000 rows x 2 columns]

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ## Cleansing

# %%
import re

def clean_text(df, text_field, new_text_field_name):
    # Mengubah teks menjadi huruf kecil
    df[new_text_field_name] = df[text_field].str.lower()  
    # Menhapus tanda baca, emotikon, dan karakter khusus yang tidak dibutuhkan
    df[new_text_field_name] = df[new_text_field_name].apply(lambda x: re.sub(r"(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", x))
    # Menhapus angka pada teks
    df[new_text_field_name] = df[new_text_field_name].apply(lambda x: re.sub(r"\d+", "", x))
    
    return df

# %%
# Memanggil fungsi clean_text
data_preproc = clean_text(data_preproc, 'content', 'cleaned_content')

# Menampilkan hasil
data_preproc
# Out:
#                                                 content sentiment  \
# 0     Sumpah aplikasi ini bikin gw kesel sendiri. Ud...   Negatif
# 1     lumayan bagus tapi tolong di perbaiki gangguan...   Positif
# 2     Bagus banget Jadi bisa lihat TV dimn pun saat ...   Positif
# 3     Masa tidak bisa tampilkan semua liga, kami mau...   Negatif
# 4     Kayaknya aplikasi OONA lebih bagus, bagi yg ke...   Negatif
# ...                                                 ...       ...
# 9995  Aplikasi dari 2015 tapi film dan anime yang te...   Negatif
# 9996  Saya menyesal berlanggan vidio karena pembayar...   Negatif
# 9997  tolong apknya di update dong masa gak ada film...   Negatif
# 9998  masa nonton premier league vidionya lebih lamb...   Negatif
# 9999     Kurang bagus aplikasinya, terlalu banyak iklan   Negatif
#
#                                         cleaned_content
# 0     sumpah aplikasi ini bikin gw kesel sendiri uda...
# 1     lumayan bagus tapi tolong di perbaiki gangguan...
# 2     bagus banget jadi bisa lihat tv dimn pun saat ...
# 3     masa tidak bisa tampilkan semua liga kami mau ...
# 4     kayaknya aplikasi oona lebih bagus bagi yg kec...
# ...                                                 ...
# 9995  aplikasi dari  tapi film dan anime yang tersed...
# 9996  saya menyesal berlanggan vidio karena pembayar...
# 9997  tolong apknya di update dong masa gak ada film...
# 9998  masa nonton premier league vidionya lebih lamb...
# 9999      kurang bagus aplikasinya terlalu banyak iklan
#
# [10000 rows x 3 columns]

# %% [markdown]
# ## Stopwords Removal

# %%
"""
from nltk.corpus import stopwords
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# Mengunduh stopwords bahasa Indonesia dari NLTK
stopwords_indonesia = set(stopwords.words('indonesian'))

# Mengunduh stopwords bahasa Indonesia dari Sastrawi
stopword_factory = StopWordRemoverFactory()
stopword_sastrawi = stopword_factory.create_stop_word_remover()

# Menambahkan stopwords khusus tambahan jika diperlukan
custom_stopwords = set(["tambahan", "lainnya"])

# Menggabungkan semua stopwords
stopwords_total = stopwords_indonesia.union(custom_stopwords)

# Fungsi untuk melakukan stopwords removal
def remove_stopwords(text):
    tokens = text.split()
    filtered_tokens = [word for word in tokens if word not in stopwords_total]
    return ' '.join(filtered_tokens)
    
# Mengaplikasikan stopwords removal pada data
data_preproc['cleaned_content_stopwords'] = data_preproc['cleaned_content'].apply(remove_stopwords)

# Menampilkan hasil
data_preproc['cleaned_content_stopwords']
"""

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download stopwords untuk bahasa Indonesia (lakukan sekali saja)
import nltk
nltk.download('stopwords')
nltk.download('punkt')

# Daftar stopwords dalam bahasa Indonesia
stop_words = set(stopwords.words('indonesian'))

# Fungsi untuk menghapus stopwords dari teks
def remove_stopwords(text):
    words = word_tokenize(text)
    filtered_words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(filtered_words)

# Terapkan fungsi pada kolom yang bersih
data_preproc['cleaned_content_stopwords'] = data_preproc['cleaned_content'].apply(remove_stopwords)

# Tampilkan hasil
data_preproc
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                                 content sentiment  \
# 0     Sumpah aplikasi ini bikin gw kesel sendiri. Ud...   Negatif
# 1     lumayan bagus tapi tolong di perbaiki gangguan...   Positif
# 2     Bagus banget Jadi bisa lihat TV dimn pun saat ...   Positif
# 3     Masa tidak bisa tampilkan semua liga, kami mau...   Negatif
# 4     Kayaknya aplikasi OONA lebih bagus, bagi yg ke...   Negatif
# ...                                                 ...       ...
# 9995  Aplikasi dari 2015 tapi film dan anime yang te...   Negatif
# 9996  Saya menyesal berlanggan vidio karena pembayar...   Negatif
# 9997  tolong apknya di update dong masa gak ada film...   Negatif
# 9998  masa nonton premier league vidionya lebih lamb...   Negatif
# 9999     Kurang bagus aplikasinya, terlalu banyak iklan   Negatif
#
#                                         cleaned_content  \
# 0     sumpah aplikasi ini bikin gw kesel sendiri uda...
# 1     lumayan bagus tapi tolong di perbaiki gangguan...
# 2     bagus banget jadi bisa lihat tv dimn pun saat ...
# 3     masa tidak bisa tampilkan semua liga kami mau ...
# 4     kayaknya aplikasi oona lebih bagus bagi yg kec...
# ...                                                 ...
# 9995  aplikasi dari  tapi film dan anime yang tersed...
# 9996  saya menyesal berlanggan vidio karena pembayar...
# 9997  tolong apknya di update dong masa gak ada film...
# 9998  masa nonton premier league vidionya lebih lamb...
# 9999      kurang bagus aplikasinya terlalu banyak iklan
#
#                               cleaned_content_stopwords
# 0     sumpah aplikasi bikin gw kesel udah gw hapus t...
# 1     lumayan bagus tolong perbaiki gangguan nya cha...
# 2     bagus banget lihat tv dimn bepergian jarak jau...
# 3     tampilkan liga nntin laliga liga champion tpi ...
# 4     kayaknya aplikasi oona bagus yg kecewa dgn apl...
# ...                                                 ...
# 9995  aplikasi film anime tersedia film anime tersed...
# 9996  menyesal berlanggan vidio pembayaran otomatis ...
# 9997      tolong apknya update gak film midnight runner
# 9998  nonton premier league vidionya lambat situs il...
# 9999                            bagus aplikasinya iklan
#
# [10000 rows x 4 columns]

# %% [markdown]
# ## Tokenisasi Kata

# %%
from nltk.tokenize import word_tokenize

# Fungsi untuk tokenisasi teks
def tokenize_text(text):
    tokens = word_tokenize(text)
    return tokens

# Terapkan fungsi pada kolom yang sudah dihapus stopwords
data_preproc['tokenize_content'] = data_preproc['cleaned_content_stopwords'].apply(tokenize_text)

# Tampilkan hasil
data_preproc
# Out:
#                                                 content sentiment  \
# 0     Sumpah aplikasi ini bikin gw kesel sendiri. Ud...   Negatif
# 1     lumayan bagus tapi tolong di perbaiki gangguan...   Positif
# 2     Bagus banget Jadi bisa lihat TV dimn pun saat ...   Positif
# 3     Masa tidak bisa tampilkan semua liga, kami mau...   Negatif
# 4     Kayaknya aplikasi OONA lebih bagus, bagi yg ke...   Negatif
# ...                                                 ...       ...
# 9995  Aplikasi dari 2015 tapi film dan anime yang te...   Negatif
# 9996  Saya menyesal berlanggan vidio karena pembayar...   Negatif
# 9997  tolong apknya di update dong masa gak ada film...   Negatif
# 9998  masa nonton premier league vidionya lebih lamb...   Negatif
# 9999     Kurang bagus aplikasinya, terlalu banyak iklan   Negatif
#
#                                         cleaned_content  \
# 0     sumpah aplikasi ini bikin gw kesel sendiri uda...
# 1     lumayan bagus tapi tolong di perbaiki gangguan...
# 2     bagus banget jadi bisa lihat tv dimn pun saat ...
# 3     masa tidak bisa tampilkan semua liga kami mau ...
# 4     kayaknya aplikasi oona lebih bagus bagi yg kec...
# ...                                                 ...
# 9995  aplikasi dari  tapi film dan anime yang tersed...
# 9996  saya menyesal berlanggan vidio karena pembayar...
# 9997  tolong apknya di update dong masa gak ada film...
# 9998  masa nonton premier league vidionya lebih lamb...
# 9999      kurang bagus aplikasinya terlalu banyak iklan
#
#                               cleaned_content_stopwords  \
# 0     sumpah aplikasi bikin gw kesel udah gw hapus t...
# 1     lumayan bagus tolong perbaiki gangguan nya cha...
# 2     bagus banget lihat tv dimn bepergian jarak jau...
# 3     tampilkan liga nntin laliga liga champion tpi ...
# 4     kayaknya aplikasi oona bagus yg kecewa dgn apl...
# ...                                                 ...
# 9995  aplikasi film anime tersedia film anime tersed...
# 9996  menyesal berlanggan vidio pembayaran otomatis ...
# 9997      tolong apknya update gak film midnight runner
# 9998  nonton premier league vidionya lambat situs il...
# 9999                            bagus aplikasinya iklan
#
#                                        tokenize_content
# 0     [sumpah, aplikasi, bikin, gw, kesel, udah, gw,...
# 1     [lumayan, bagus, tolong, perbaiki, gangguan, n...
# 2     [bagus, banget, lihat, tv, dimn, bepergian, ja...
# 3     [tampilkan, liga, nntin, laliga, liga, champio...
# 4     [kayaknya, aplikasi, oona, bagus, yg, kecewa, ...
# ...                                                 ...
# 9995  [aplikasi, film, anime, tersedia, film, anime,...
# 9996  [menyesal, berlanggan, vidio, pembayaran, otom...
# 9997  [tolong, apknya, update, gak, film, midnight, ...
# 9998  [nonton, premier, league, vidionya, lambat, si...
# 9999                        [bagus, aplikasinya, iklan]
#
# [10000 rows x 5 columns]

# %% [markdown]
# ## Postag Text

# %%
# Mengunduh model CRF tagger untuk Bahasa Indonesia
ct = CRFTagger()
ct.set_model_file('all_indo_man_tag_corpus_model.crf.tagger')

# Fungsi untuk melakukan tokenisasi dan postagging
def postag_text(text):
    # Tokenisasi teks
    tokens = word_tokenize(text)

    # Melakukan postagging menggunakan CRFTagger
    postags = ct.tag_sents([tokens])

    return postags[0]  # Kembalikan hasil postag untuk teks pertama

# Terapkan fungsi pada kolom yang telah dihapus stopwords
data_preproc['pos_tags_content'] = data_preproc['cleaned_content_stopwords'].apply(postag_text)

# Tampilkan hasil
data_preproc
# Out:
#                                                 content sentiment  \
# 0     Sumpah aplikasi ini bikin gw kesel sendiri. Ud...   Negatif
# 1     lumayan bagus tapi tolong di perbaiki gangguan...   Positif
# 2     Bagus banget Jadi bisa lihat TV dimn pun saat ...   Positif
# 3     Masa tidak bisa tampilkan semua liga, kami mau...   Negatif
# 4     Kayaknya aplikasi OONA lebih bagus, bagi yg ke...   Negatif
# ...                                                 ...       ...
# 9995  Aplikasi dari 2015 tapi film dan anime yang te...   Negatif
# 9996  Saya menyesal berlanggan vidio karena pembayar...   Negatif
# 9997  tolong apknya di update dong masa gak ada film...   Negatif
# 9998  masa nonton premier league vidionya lebih lamb...   Negatif
# 9999     Kurang bagus aplikasinya, terlalu banyak iklan   Negatif
#
#                                         cleaned_content  \
# 0     sumpah aplikasi ini bikin gw kesel sendiri uda...
# 1     lumayan bagus tapi tolong di perbaiki gangguan...
# 2     bagus banget jadi bisa lihat tv dimn pun saat ...
# 3     masa tidak bisa tampilkan semua liga kami mau ...
# 4     kayaknya aplikasi oona lebih bagus bagi yg kec...
# ...                                                 ...
# 9995  aplikasi dari  tapi film dan anime yang tersed...
# 9996  saya menyesal berlanggan vidio karena pembayar...
# 9997  tolong apknya di update dong masa gak ada film...
# 9998  masa nonton premier league vidionya lebih lamb...
# 9999      kurang bagus aplikasinya terlalu banyak iklan
#
#                               cleaned_content_stopwords  \
# 0     sumpah aplikasi bikin gw kesel udah gw hapus t...
# 1     lumayan bagus tolong perbaiki gangguan nya cha...
# 2     bagus banget lihat tv dimn bepergian jarak jau...
# 3     tampilkan liga nntin laliga liga champion tpi ...
# 4     kayaknya aplikasi oona bagus yg kecewa dgn apl...
# ...                                                 ...
# 9995  aplikasi film anime tersedia film anime tersed...
# 9996  menyesal berlanggan vidio pembayaran otomatis ...
# 9997      tolong apknya update gak film midnight runner
# 9998  nonton premier league vidionya lambat situs il...
# 9999                            bagus aplikasinya iklan
#
#                                        tokenize_content  \
# 0     [sumpah, aplikasi, bikin, gw, kesel, udah, gw,...
# 1     [lumayan, bagus, tolong, perbaiki, gangguan, n...
# 2     [bagus, banget, lihat, tv, dimn, bepergian, ja...
# 3     [tampilkan, liga, nntin, laliga, liga, champio...
# 4     [kayaknya, aplikasi, oona, bagus, yg, kecewa, ...
# ...                                                 ...
# 9995  [aplikasi, film, anime, tersedia, film, anime,...
# 9996  [menyesal, berlanggan, vidio, pembayaran, otom...
# 9997  [tolong, apknya, update, gak, film, midnight, ...
# 9998  [nonton, premier, league, vidionya, lambat, si...
# 9999                        [bagus, aplikasinya, iklan]
#
#                                        pos_tags_content
# 0     [(sumpah, NN), (aplikasi, NN), (bikin, FW), (g...
# 1     [(lumayan, NN), (bagus, JJ), (tolong, VB), (pe...
# 2     [(bagus, JJ), (banget, NN), (lihat, VB), (tv, ...
# 3     [(tampilkan, VB), (liga, CD), (nntin, NN), (la...
# 4     [(kayaknya, RB), (aplikasi, VB), (oona, NN), (...
# ...                                                 ...
# 9995  [(aplikasi, NN), (film, NN), (anime, NN), (ter...
# 9996  [(menyesal, NN), (berlanggan, NN), (vidio, NN)...
# 9997  [(tolong, VB), (apknya, RB), (update, FW), (ga...
# 9998  [(nonton, FW), (premier, FW), (league, FW), (v...
# 9999      [(bagus, JJ), (aplikasinya, RB), (iklan, VB)]
#
# [10000 rows x 6 columns]

# %% [markdown]
# ## get selected tags (Indexed Content)

# %%
def get_selected_tags(tokens_with_tags):
    selected_tags = ['NN', 'VB', 'JJ', 'RB']
    return [text for text, tag in tokens_with_tags if tag in selected_tags]

# Terapkan fungsi pada kolom 'postag_content'
data_preproc['indexed_content'] = data_preproc['pos_tags_content'].apply(get_selected_tags)

data_preproc
# Out:
#                                                 content sentiment  \
# 0     Sumpah aplikasi ini bikin gw kesel sendiri. Ud...   Negatif
# 1     lumayan bagus tapi tolong di perbaiki gangguan...   Positif
# 2     Bagus banget Jadi bisa lihat TV dimn pun saat ...   Positif
# 3     Masa tidak bisa tampilkan semua liga, kami mau...   Negatif
# 4     Kayaknya aplikasi OONA lebih bagus, bagi yg ke...   Negatif
# ...                                                 ...       ...
# 9995  Aplikasi dari 2015 tapi film dan anime yang te...   Negatif
# 9996  Saya menyesal berlanggan vidio karena pembayar...   Negatif
# 9997  tolong apknya di update dong masa gak ada film...   Negatif
# 9998  masa nonton premier league vidionya lebih lamb...   Negatif
# 9999     Kurang bagus aplikasinya, terlalu banyak iklan   Negatif
#
#                                         cleaned_content  \
# 0     sumpah aplikasi ini bikin gw kesel sendiri uda...
# 1     lumayan bagus tapi tolong di perbaiki gangguan...
# 2     bagus banget jadi bisa lihat tv dimn pun saat ...
# 3     masa tidak bisa tampilkan semua liga kami mau ...
# 4     kayaknya aplikasi oona lebih bagus bagi yg kec...
# ...                                                 ...
# 9995  aplikasi dari  tapi film dan anime yang tersed...
# 9996  saya menyesal berlanggan vidio karena pembayar...
# 9997  tolong apknya di update dong masa gak ada film...
# 9998  masa nonton premier league vidionya lebih lamb...
# 9999      kurang bagus aplikasinya terlalu banyak iklan
#
#                               cleaned_content_stopwords  \
# 0     sumpah aplikasi bikin gw kesel udah gw hapus t...
# 1     lumayan bagus tolong perbaiki gangguan nya cha...
# 2     bagus banget lihat tv dimn bepergian jarak jau...
# 3     tampilkan liga nntin laliga liga champion tpi ...
# 4     kayaknya aplikasi oona bagus yg kecewa dgn apl...
# ...                                                 ...
# 9995  aplikasi film anime tersedia film anime tersed...
# 9996  menyesal berlanggan vidio pembayaran otomatis ...
# 9997      tolong apknya update gak film midnight runner
# 9998  nonton premier league vidionya lambat situs il...
# 9999                            bagus aplikasinya iklan
#
#                                        tokenize_content  \
# 0     [sumpah, aplikasi, bikin, gw, kesel, udah, gw,...
# 1     [lumayan, bagus, tolong, perbaiki, gangguan, n...
# 2     [bagus, banget, lihat, tv, dimn, bepergian, ja...
# 3     [tampilkan, liga, nntin, laliga, liga, champio...
# 4     [kayaknya, aplikasi, oona, bagus, yg, kecewa, ...
# ...                                                 ...
# 9995  [aplikasi, film, anime, tersedia, film, anime,...
# 9996  [menyesal, berlanggan, vidio, pembayaran, otom...
# 9997  [tolong, apknya, update, gak, film, midnight, ...
# 9998  [nonton, premier, league, vidionya, lambat, si...
# 9999                        [bagus, aplikasinya, iklan]
#
#                                        pos_tags_content  \
# 0     [(sumpah, NN), (aplikasi, NN), (bikin, FW), (g...
# 1     [(lumayan, NN), (bagus, JJ), (tolong, VB), (pe...
# 2     [(bagus, JJ), (banget, NN), (lihat, VB), (tv, ...
# 3     [(tampilkan, VB), (liga, CD), (nntin, NN), (la...
# 4     [(kayaknya, RB), (aplikasi, VB), (oona, NN), (...
# ...                                                 ...
# 9995  [(aplikasi, NN), (film, NN), (anime, NN), (ter...
# 9996  [(menyesal, NN), (berlanggan, NN), (vidio, NN)...
# 9997  [(tolong, VB), (apknya, RB), (update, FW), (ga...
# 9998  [(nonton, FW), (premier, FW), (league, FW), (v...
# 9999      [(bagus, JJ), (aplikasinya, RB), (iklan, VB)]
#
#                                         indexed_content
# 0     [sumpah, aplikasi, ulang, aja, ga, dibuka, buk...
# 1     [lumayan, bagus, tolong, perbaiki, gangguan, n...
# 2     [bagus, banget, lihat, tv, dimn, bepergian, ja...
# 3     [tampilkan, nntin, tpi, mala, tdk, alasannya, ...
# 4     [kayaknya, aplikasi, oona, bagus, yg, kecewa, ...
# ...                                                 ...
# 9995  [aplikasi, film, anime, tersedia, film, anime,...
# 9996  [menyesal, berlanggan, vidio, pembayaran, otom...
# 9997                                   [tolong, apknya]
# 9998  [vidionya, lambat, situs, ilegal, official, pa...
# 9999                        [bagus, aplikasinya, iklan]
#
# [10000 rows x 7 columns]

# %% [markdown]
# ## Lemma Content

# %%
# Menggabungkan lema ke dalam teks
data_preproc['lemmas_to_content'] = data_preproc['indexed_content'].apply(lambda lemmas: ' '.join(map(str, lemmas)))

data_preproc
# Out:
#                                                 content sentiment  \
# 0     Sumpah aplikasi ini bikin gw kesel sendiri. Ud...   Negatif
# 1     lumayan bagus tapi tolong di perbaiki gangguan...   Positif
# 2     Bagus banget Jadi bisa lihat TV dimn pun saat ...   Positif
# 3     Masa tidak bisa tampilkan semua liga, kami mau...   Negatif
# 4     Kayaknya aplikasi OONA lebih bagus, bagi yg ke...   Negatif
# ...                                                 ...       ...
# 9995  Aplikasi dari 2015 tapi film dan anime yang te...   Negatif
# 9996  Saya menyesal berlanggan vidio karena pembayar...   Negatif
# 9997  tolong apknya di update dong masa gak ada film...   Negatif
# 9998  masa nonton premier league vidionya lebih lamb...   Negatif
# 9999     Kurang bagus aplikasinya, terlalu banyak iklan   Negatif
#
#                                         cleaned_content  \
# 0     sumpah aplikasi ini bikin gw kesel sendiri uda...
# 1     lumayan bagus tapi tolong di perbaiki gangguan...
# 2     bagus banget jadi bisa lihat tv dimn pun saat ...
# 3     masa tidak bisa tampilkan semua liga kami mau ...
# 4     kayaknya aplikasi oona lebih bagus bagi yg kec...
# ...                                                 ...
# 9995  aplikasi dari  tapi film dan anime yang tersed...
# 9996  saya menyesal berlanggan vidio karena pembayar...
# 9997  tolong apknya di update dong masa gak ada film...
# 9998  masa nonton premier league vidionya lebih lamb...
# 9999      kurang bagus aplikasinya terlalu banyak iklan
#
#                               cleaned_content_stopwords  \
# 0     sumpah aplikasi bikin gw kesel udah gw hapus t...
# 1     lumayan bagus tolong perbaiki gangguan nya cha...
# 2     bagus banget lihat tv dimn bepergian jarak jau...
# 3     tampilkan liga nntin laliga liga champion tpi ...
# 4     kayaknya aplikasi oona bagus yg kecewa dgn apl...
# ...                                                 ...
# 9995  aplikasi film anime tersedia film anime tersed...
# 9996  menyesal berlanggan vidio pembayaran otomatis ...
# 9997      tolong apknya update gak film midnight runner
# 9998  nonton premier league vidionya lambat situs il...
# 9999                            bagus aplikasinya iklan
#
#                                        tokenize_content  \
# 0     [sumpah, aplikasi, bikin, gw, kesel, udah, gw,...
# 1     [lumayan, bagus, tolong, perbaiki, gangguan, n...
# 2     [bagus, banget, lihat, tv, dimn, bepergian, ja...
# 3     [tampilkan, liga, nntin, laliga, liga, champio...
# 4     [kayaknya, aplikasi, oona, bagus, yg, kecewa, ...
# ...                                                 ...
# 9995  [aplikasi, film, anime, tersedia, film, anime,...
# 9996  [menyesal, berlanggan, vidio, pembayaran, otom...
# 9997  [tolong, apknya, update, gak, film, midnight, ...
# 9998  [nonton, premier, league, vidionya, lambat, si...
# 9999                        [bagus, aplikasinya, iklan]
#
#                                        pos_tags_content  \
# 0     [(sumpah, NN), (aplikasi, NN), (bikin, FW), (g...
# 1     [(lumayan, NN), (bagus, JJ), (tolong, VB), (pe...
# 2     [(bagus, JJ), (banget, NN), (lihat, VB), (tv, ...
# 3     [(tampilkan, VB), (liga, CD), (nntin, NN), (la...
# 4     [(kayaknya, RB), (aplikasi, VB), (oona, NN), (...
# ...                                                 ...
# 9995  [(aplikasi, NN), (film, NN), (anime, NN), (ter...
# 9996  [(menyesal, NN), (berlanggan, NN), (vidio, NN)...
# 9997  [(tolong, VB), (apknya, RB), (update, FW), (ga...
# 9998  [(nonton, FW), (premier, FW), (league, FW), (v...
# 9999      [(bagus, JJ), (aplikasinya, RB), (iklan, VB)]
#
#                                         indexed_content  \
# 0     [sumpah, aplikasi, ulang, aja, ga, dibuka, buk...
# 1     [lumayan, bagus, tolong, perbaiki, gangguan, n...
# 2     [bagus, banget, lihat, tv, dimn, bepergian, ja...
# 3     [tampilkan, nntin, tpi, mala, tdk, alasannya, ...
# 4     [kayaknya, aplikasi, oona, bagus, yg, kecewa, ...
# ...                                                 ...
# 9995  [aplikasi, film, anime, tersedia, film, anime,...
# 9996  [menyesal, berlanggan, vidio, pembayaran, otom...
# 9997                                   [tolong, apknya]
# 9998  [vidionya, lambat, situs, ilegal, official, pa...
# 9999                        [bagus, aplikasinya, iklan]
#
#                                       lemmas_to_content
# 0     sumpah aplikasi ulang aja ga dibuka buka muncu...
# 1     lumayan bagus tolong perbaiki gangguan nya cha...
# 2     bagus banget lihat tv dimn bepergian jarak jau...
# 3     tampilkan nntin tpi mala tdk alasannya hak cip...
# 4     kayaknya aplikasi oona bagus yg kecewa dgn apl...
# ...                                                 ...
# 9995  aplikasi film anime tersedia film anime tersed...
# 9996  menyesal berlanggan vidio pembayaran otomatis ...
# 9997                                      tolong apknya
# 9998  vidionya lambat situs ilegal official partner ...
# 9999                            bagus aplikasinya iklan
#
# [10000 rows x 8 columns]

# %% [markdown]
# ## Stemming Data kolom yang sudah di Tokenisasi

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
#-----------------STEMMING -----------------
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# buat stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# proses stemming
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}
hitung=0

for document in data_preproc['tokenize_content']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '

print(len(term_dict))
print("------------------------")
for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    hitung+=1
    print(hitung,":",term,":" ,term_dict[term])

print(term_dict)
print("------------------------")

def get_stemmed_term(document):
    return [term_dict[term] for term in document]
# Out:
# 17375
# ------------------------
# 1 : sumpah : sumpah
# 2 : aplikasi : aplikasi
# 3 : bikin : bikin
# 4 : gw : gw
# 5 : kesel : kesel
# 6 : udah : udah
# 7 : hapus : hapus
# 8 : trs : trs
# 9 : download : download
# 10 : ulang : ulang
# 11 : aja : aja
# 12 : ga : ga
# 13 : dibuka : buka
# 14 : buka : buka
# 15 : munculnya : muncul
# 16 : layar : layar
# 17 : putih : putih
# 18 : doang : doang
# 19 : gatau : gatau
# 20 : gada : gada
# 21 : kendala : kendala
# 22 : lumayan : lumayan
# 23 : bagus : bagus
# 24 : tolong : tolong
# 25 : perbaiki : baik
# 26 : gangguan : ganggu
# 27 : nya : nya
# 28 : channel : channel
# 29 : putar : putar
# 30 : banget : banget
# 31 : lihat : lihat
# 32 : tv : tv
# 33 : dimn : dimn
# 34 : bepergian : pergi
# 35 : jarak : jarak
# 36 : jauhdekat : jauhdekat
# 37 : mati : mati
# 38 : lampulistrik : lampulistrik
# 39 : dlln : dlln
# 40 : tampilkan : tampil
# 41 : liga : liga
# 42 : nntin : nntin
# 43 : laliga : laliga
# 44 : champion : champion
# 45 : tpi : tpi
# 46 : mala : mala
# 47 : tdk : tdk
# 48 : alasannya : alas
# 49 : hak : hak
# 50 : cipta : cipta
# 51 : bayar : bayar
# 52 : ka : ka
# 53 : sda : sda
# 54 : penggemar : gemar
# 55 : pendapatan : dapat
# 56 : jg : jg
# 57 : bnyak : bnyak
# 58 : kayaknya : kayak
# 59 : oona : oona
# 60 : yg : yg
# 61 : kecewa : kecewa
# 62 : dgn : dgn
# 63 : mending : mending
# 64 : diplaystore : diplaystore
# 65 : masukin : masukin
# 66 : kode : kode
# 67 : aktivasi : aktivasi
# 68 : suliun : suliun
# 69 : klik : klik
# 70 : masuk : masuk
# 71 : log : log
# 72 : in : in
# 73 : via : via
# 74 : instagram : instagram
# 75 : biar : biar
# 76 : mudah : mudah
# 77 : bagaimna : bagaimna
# 78 : sih : sih
# 79 : koneksi : koneksi
# 80 : data : data
# 81 : youtube : youtube
# 82 : smua : smua
# 83 : cuman : cuman
# 84 : katax : katax
# 85 : tdak : tdak
# 86 : pas : pas
# 87 : nonton : nonton
# 88 : video : video
# 89 : kuota : kuota
# 90 : videomaxnya : videomaxnya
# 91 : gk : gk
# 92 : kepake : kepake
# 93 : lokalnya : lokal
# 94 : ama : ama
# 95 : internetnya : internetnya
# 96 : ambil : ambil
# 97 : acara : acara
# 98 : x : x
# 99 : kalo : kalo
# 100 : nyari : nyari
# 101 : lgi : lgi
# 102 : pake : pake
# 103 : alasan : alas
# 104 : sya : sya
# 105 : tu : tu
# 106 : thank : thank
# 107 : you : you
# 108 : and : and
# 109 : good : good
# 110 : by : by
# 111 : click : click
# 112 : to : to
# 113 : link : link
# 114 : from : from
# 115 : yesterday : yesterday
# 116 : at : at
# 117 : the : the
# 118 : top : top
# 119 : right : right
# 120 : now : now
# 121 : because : because
# 122 : this : this
# 123 : started : started
# 124 : playing : playing
# 125 : on : on
# 126 : another : another
# 127 : device : device
# 128 : akhirat : akhirat
# 129 : kelak : kelak
# 130 : lepas : lepas
# 131 : peran : peran
# 132 : kehidupan : hidup
# 133 : seharihari : seharihari
# 134 : bro : bro
# 135 : mantap : mantap
# 136 : mendukung : dukung
# 137 : chromecast : chromecast
# 138 : siaran : siar
# 139 : lokal : lokal
# 140 : gak : gak
# 141 : antena : antena
# 142 : gambar : gambar
# 143 : full : full
# 144 : hd : hd
# 145 : play : play
# 146 : lancar : lancar
# 147 : pilih : pilih
# 148 : kualitas : kualitas
# 149 : suka : suka
# 150 : ajah : ajah
# 151 : bosan : bosan
# 152 : tambahin : tambahin
# 153 : chanel : chanel
# 154 : bein : bein
# 155 : sport : sport
# 156 : zee : zee
# 157 : bioskop : bioskop
# 158 : dll : dll
# 159 : assalamualaikum : assalamualaikum
# 160 : saudara : saudara
# 161 : ku : ku
# 162 : cintai : cinta
# 163 : banggakan : bangga
# 164 : lahhh : lahhh
# 165 : bermanfaat : manfaat
# 166 : manusia : manusia
# 167 : macet : macet
# 168 : lemot : lot
# 169 : ngelek : ngelek
# 170 : lancarrrrr : lancarrrrr
# 171 : pokoe : pokoe
# 172 : uapikkk : uapikkk
# 173 : tenaaannnn : tenaaannnn
# 174 : reekkkk : reekkkk
# 175 : matursuwun : matursuwun
# 176 : wassalamualaikum : wassalamualaikum
# 177 : beda : beda
# 178 : cepet : cepet
# 179 : lambat : lambat
# 180 : aplikasinya : aplikasi
# 181 : bug : bug
# 182 : mengganggu : ganggu
# 183 : versi : versi
# 184 : back : back
# 185 : android : android
# 186 : box : box
# 187 : ntah : ntah
# 188 : pakai : pakai
# 189 : remot : remot
# 190 : mouse : mouse
# 191 : min : min
# 192 : fullscreen : fullscreen
# 193 : miring : miring
# 194 : sisi : sisi
# 195 : otomatis : otomatis
# 196 : nyala : nyala
# 197 : app : app
# 198 : tp : tp
# 199 : knp : knp
# 200 : stelah : stelah
# 201 : d : d
# 202 : update : update
# 203 : loading : loading
# 204 : y : y
# 205 : sinyal : sinyal
# 206 : sekalitolong : sekalitolong
# 207 : pengguna : guna
# 208 : solusinya : solusi
# 209 : terimakasih : terimakasih
# 210 : upload : upload
# 211 : videononton : videononton
# 212 : monetesi : monetesi
# 213 : videojangan : videojangan
# 214 : ragu : ragu
# 215 : yagak : yagak
# 216 : mengecewakanbintang : mengecewakanbintang
# 217 : deh : deh
# 218 : lamalama : lamalama
# 219 : please : please
# 220 : jernih : jernih
# 221 : lengkap : lengkap
# 222 : hp : hp
# 223 : sampe : sampe
# 224 : panas : panas
# 225 : nungguin : nungguin
# 226 : jujur : jujur
# 227 : bersemangat : semangat
# 228 : menginstal : menginstal
# 229 : berhasil : hasil
# 230 : mengunggah : unggah
# 231 : kalinya : kali
# 232 : selesai : selesai
# 233 : muncul : muncul
# 234 : menghabiskan : habis
# 235 : coba : coba
# 236 : jelek : jelek
# 237 : buruk : buruk
# 238 : diperbaiki : baik
# 239 : terbaru : baru
# 240 : error : error
# 241 : tombol : tombol
# 242 : fungsi : fungsi
# 243 : sperti : sperti
# 244 : sbelumnya : sbelumnya
# 245 : v : v
# 246 : bagusini : bagusini
# 247 : bagusbisa : bagusbisa
# 248 : solusi : solusi
# 249 : bola : bola
# 250 : acaktapi : acaktapi
# 251 : lagikarna : lagikarna
# 252 : streaming : streaming
# 253 : samajadinya : samajadinya
# 254 : nge : nge
# 255 : lagnya : lagnya
# 256 : ampuntolong : ampuntolong
# 257 : ya : ya
# 258 : terima : terima
# 259 : kasih : kasih
# 260 : berjalan : jalan
# 261 : samsung : samsung
# 262 : core : core
# 263 : prime : prime
# 264 : memotar : memotar
# 265 : bacaan : baca
# 266 : strmng : strmng
# 267 : penyebabnya : sebab
# 268 : senang : senang
# 269 : memgapload : memgapload
# 270 : ngak : ngak
# 271 : ganti : ganti
# 272 : tapiiiiiiiii : tapiiiiiiiii
# 273 : masalahx : masalahx
# 274 : loadingnya : loadingnya
# 275 : asik : asik
# 276 : langsung : langsung
# 277 : huuufffttt : huuufffttt
# 278 : ftv : ftv
# 279 : diputar : putar
# 280 : wni : wni
# 281 : merantau : rantau
# 282 : kadang : kadang
# 283 : not : not
# 284 : available : available
# 285 : for : for
# 286 : your : your
# 287 : region : region
# 288 : piala : piala
# 289 : afc : afc
# 290 : keluarnya : keluar
# 291 : tayang : tayang
# 292 : karna : karna
# 293 : siar : siar
# 294 : krna : krna
# 295 : apk : apk
# 296 : pertandingan : tanding
# 297 : mengecewakan : kecewa
# 298 : otw : otw
# 299 : uninstal : uninstal
# 300 : puas : puas
# 301 : tambahkan : tambah
# 302 : merefresh : merefresh
# 303 : aplikasiblain : aplikasiblain
# 304 : tarik : tarik
# 305 : kebawah : bawah
# 306 : sudut : sudut
# 307 : kanan : kanan
# 308 : hilang : hilang
# 309 : terhenti : henti
# 310 : koneksinya : koneksi
# 311 : terpaksa : paksa
# 312 : n : n
# 313 : videonya : video
# 314 : mencari : cari
# 315 : batas : batas
# 316 : ditonton : tonton
# 317 : pengalamanku : alam
# 318 : maaf : maaf
# 319 : fitur : fitur
# 320 : history : history
# 321 : tontonan : tonton
# 322 : spt : spt
# 323 : susah : susah
# 324 : jeda : jeda
# 325 : lg : lg
# 326 : search : search
# 327 : mengulang : ulang
# 328 : ribet : ribet
# 329 : pokoknya : pokok
# 330 : tontontan : tontontan
# 331 : bintang : bintang
# 332 : diadain : diadain
# 333 : fiturnya : fiturnya
# 334 : champions : champions
# 335 : fungsinya : fungsi
# 336 : duh : duh
# 337 : pantasnya : pantas
# 338 : wifi : wifi
# 339 : skip : skip
# 340 : aneh : aneh
# 341 : tolng : tolng
# 342 : sistem : sistem
# 343 : baguss : baguss
# 344 : yah : yah
# 345 : sinyalnya : sinyal
# 346 : kuatmohon : kuatmohon
# 347 : masukannya : masuk
# 348 : iklan : iklan
# 349 : menjengkelkan : jengkel
# 350 : berkalikali : berkalikali
# 351 : sebenernya : sebenernya
# 352 : moto : moto
# 353 : gp : gp
# 354 : trans : trans
# 355 : ko : ko
# 356 : sihh : sihh
# 357 : simple : simple
# 358 : pke : pke
# 359 : kabel : kabel
# 360 : manapun : mana
# 361 : indosiar : indosiar
# 362 : liat : liat
# 363 : flim : flim
# 364 : favorite : favorite
# 365 : thanks : thanks
# 366 : berbeda : beda
# 367 : tampilan : tampil
# 368 : best : best
# 369 : nayangin : nayangin
# 370 : tim : tim
# 371 : favoritku : favorit
# 372 : komentar : komentar
# 373 : pikirkan : pikir
# 374 : kenyamanan : nyaman
# 375 : stasiun : stasiun
# 376 : psm : psm
# 377 : makassar : makassar
# 378 : main : main
# 379 : live : live
# 380 : bersaing : saing
# 381 : maksudnya : maksud
# 382 : ditayangkan : tayang
# 383 : udh : udh
# 384 : keren : keren
# 385 : net : net
# 386 : blom : blom
# 387 : lagidi : lagidi
# 388 : tingkatkan : tingkat
# 389 : tingkat : tingkat
# 390 : kejernihan : jernih
# 391 : gambarnya : gambar
# 392 : p : p
# 393 : masukan : masuk
# 394 : k : k
# 395 : ntn : ntn
# 396 : sorryyour : sorryyour
# 397 : is : is
# 398 : supported : supported
# 399 : xiaomi : xiaomi
# 400 : mi : mi
# 401 : ram : ram
# 402 : gb : gb
# 403 : tsb : tsb
# 404 : gratis : gratis
# 405 : kouta : kouta
# 406 : vidio : vidio
# 407 : max : max
# 408 : terbantu : bantu
# 409 : semoga : moga
# 410 : cepat : cepat
# 411 : streamingnya : streamingnya
# 412 : nobufferingan : nobufferingan
# 413 : berbayarpun : bayar
# 414 : msh : msh
# 415 : layak : layak
# 416 : tayangan : tayang
# 417 : dangdut : dangdut
# 418 : academy : academy
# 419 : asiaenggak : asiaenggak
# 420 : negeritolong : negeritolong
# 421 : perbaikitrimakasih : perbaikitrimakasih
# 422 : sukses : sukses
# 423 : premier : premier
# 424 : hitungannya : hitung
# 425 : mahal : mahal
# 426 : membuka : buka
# 427 : endut : endut
# 428 : aj : aj
# 429 : klo : klo
# 430 : ntb : ntb
# 431 : sctv : sctv
# 432 : normal : normal
# 433 : penuh : penuh
# 434 : gua : gua
# 435 : minggu : minggu
# 436 : makai : maka
# 437 : ni : ni
# 438 : lelet : lelet
# 439 : sumpahh : sumpahh
# 440 : wa : wa
# 441 : fb : fb
# 442 : seluler : seluler
# 443 : tetep : tetep
# 444 : dulunya : dulunya
# 445 : mengikuti : ikut
# 446 : serial : serial
# 447 : anime : anime
# 448 : naruto : naruto
# 449 : episode : episode
# 450 : dewasa : dewasa
# 451 : apapun : apa
# 452 : amad : amad
# 453 : sorry : sorry
# 454 : uninstall : uninstall
# 455 : milik : milik
# 456 : anak : anak
# 457 : bangsa : bangsa
# 458 : terkadang : terkadang
# 459 : emtek : emtek
# 460 : lamban : lamban
# 461 : officialnya : officialnya
# 462 : develop : develop
# 463 : orang : orang
# 464 : notabene : notabene
# 465 : dibeli : beli
# 466 : bgt : bgt
# 467 : gabisa : gabisa
# 468 : jaringan : jaring
# 469 : nyoba : nyoba
# 470 : youtubeigdll : youtubeigdll
# 471 : review : review
# 472 : oke : oke
# 473 : peminat : minat
# 474 : mohon : mohon
# 475 : partisipasi : partisipasi
# 476 : show : show
# 477 : cinema : cema
# 478 : malam : malam
# 479 : gitu : gitu
# 480 : iya : iya
# 481 : begadang : begadang
# 482 : plisss : plisss
# 483 : detik : detik
# 484 : maklum : maklum
# 485 : kayak : kayak
# 486 : sebelah : belah
# 487 : menit : menit
# 488 : film : film
# 489 : pendek : pendek
# 490 : lampu : lampu
# 491 : henfon : henfon
# 492 : teri : teri
# 493 : makasih : makasih
# 494 : banyakan : banyak
# 495 : konplitin : konplitin
# 496 : inews : inews
# 497 : antv : antv
# 498 : payah : payah
# 499 : lha : lha
# 500 : terbatas : batas
# 501 : siaranya : siaranya
# 502 : usahakan : usaha
# 503 : wajar : wajar
# 504 : indonesia : indonesia
# 505 : resolusi : resolusi
# 506 : fhd : fhd
# 507 : sm : sm
# 508 : inibisa : inibisa
# 509 : membantu : bantu
# 510 : foxsport : foxsport
# 511 : sy : sy
# 512 : sngt : sngt
# 513 : berharap : harap
# 514 : trimakasih : trimakasih
# 515 : rugikan : rugi
# 516 : berlangganan : langgan
# 517 : merugikan : rugi
# 518 : akurat : akurat
# 519 : dirumah : rumah
# 520 : sinetron : sinetron
# 521 : sesuai : sesuai
# 522 : menggangu : menggangu
# 523 : handphone : handphone
# 524 : menumpuk : tumpuk
# 525 : bagusbagi : bagusbagi
# 526 : koment : koment
# 527 : mempercepatnya : cepat
# 528 : ditambahinhahaha : ditambahinhahaha
# 529 : begok : begok
# 530 : namanya : nama
# 531 : lu : lu
# 532 : emang : emang
# 533 : dipercepatklw : dipercepatklw
# 534 : mw : mw
# 535 : dipercepat : cepat
# 536 : yt : yt
# 537 : sono : sono
# 538 : akses : akses
# 539 : cz : cz
# 540 : an : an
# 541 : dg : dg
# 542 : ngebut : ngebut
# 543 : ngos : ngos
# 544 : tai : tai
# 545 : komplitmasih : komplitmasih
# 546 : bagusan : bagus
# 547 : kemanagk : kemanagk
# 548 : nyaingin : nyaingin
# 549 : youtubenyesel : youtubenyesel
# 550 : downloadtaii : downloadtaii
# 551 : vidionya : vidionya
# 552 : lagisoal : lagisoal
# 553 : loding : loding
# 554 : sekalisuka : sekalisuka
# 555 : nyendatnyendat : nyendatnyendat
# 556 : sampah : sampah
# 557 : buffering : buffering
# 558 : mulu : mulu
# 559 : enakan : enak
# 560 : dimana : mana
# 561 : kya : kya
# 562 : ngentoddddd : ngentoddddd
# 563 : mengartikan : arti
# 564 : bahasa : bahasa
# 565 : korea : korea
# 566 : subtitle : subtitle
# 567 : pdhal : pdhal
# 568 : aqw : aqw
# 569 : macetgk : macetgk
# 570 : lemotbener : lemotbener
# 571 : bener : bener
# 572 : dah : dah
# 573 : konten : konten
# 574 : primiernya : primiernya
# 575 : jgn : jgn
# 576 : tersedia : sedia
# 577 : diluar : luar
# 578 : negeri : negeri
# 579 : langganan : langgan
# 580 : berguna : guna
# 581 : ligaliga : ligaliga
# 582 : eropa : eropa
# 583 : hdterima : hdterima
# 584 : depannya : depan
# 585 : ditingkatkan : tingkat
# 586 : performasemakin : performasemakin
# 587 : menghiburthank : menghiburthank
# 588 : paket : paket
# 589 : primer : primer
# 590 : inggris : inggris
# 591 : balas : balas
# 592 : butuh : butuh
# 593 : pengembangan : kembang
# 594 : thumbnail : thumbnail
# 595 : kl : kl
# 596 : pc : pc
# 597 : informasi : informasi
# 598 : program : program
# 599 : kemitraannya : mitra
# 600 : detail : detail
# 601 : penjelasannya : jelas
# 602 : kategori : kategori
# 603 : pendidikan : didik
# 604 : kajian : kaji
# 605 : islami : islami
# 606 : rbbulan : rbbulan
# 607 : hits : hits
# 608 : sayangnya : sayang
# 609 : stb : stb
# 610 : cast : cast
# 611 : patah : patah
# 612 : dwtv : dwtv
# 613 : gtv : gtv
# 614 : email : email
# 615 : info : info
# 616 : tujuan : tuju
# 617 : nnton : nnton
# 618 : enakbuat : enakbuat
# 619 : delay : delay
# 620 : kemarin : kemarin
# 621 : jarang : jarang
# 622 : menaggapi : menaggapi
# 623 : tolonglah : tolong
# 624 : mudahan : mudah
# 625 : sepeti : sepet
# 626 : jrang : jrang
# 627 : bulanannya : bulan
# 628 : rb : rb
# 629 : menanggapi : tanggap
# 630 : darii : dari
# 631 : gara : gara
# 632 : banyakin : banyakin
# 633 : tuh : tuh
# 634 : seru : seru
# 635 : kaya : kaya
# 636 : ok : ok
# 637 : tnya : tnya
# 638 : beli : beli
# 639 : dikenakan : kena
# 640 : apl : apl
# 641 : nonnton : nonnton
# 642 : bla : bla
# 643 : uda : uda
# 644 : kow : kow
# 645 : masi : mas
# 646 : perbulan : bulan
# 647 : pls : pls
# 648 : kebalikan : balik
# 649 : bs : bs
# 650 : datanyaklw : datanyaklw
# 651 : turunkan : turun
# 652 : bintangnyaklw : bintangnyaklw
# 653 : kmbli : kmbli
# 654 : vrsi : vrsi
# 655 : br : br
# 656 : bntang : bntang
# 657 : lag : lag
# 658 : chormecastharap : chormecastharap
# 659 : memakai : pakai
# 660 : indo : indo
# 661 : lainnnsetelah : lainnnsetelah
# 662 : kali : kali
# 663 : updatelag : updatelag
# 664 : parahpadahal : parahpadahal
# 665 : apps : apps
# 666 : jaya : jaya
# 667 : menemukan : temu
# 668 : parahmohon : parahmohon
# 669 : install : install
# 670 : jelekpayah : jelekpayah
# 671 : muter : muter
# 672 : dikit : dikit
# 673 : huhhh : huhhh
# 674 : percaya : percaya
# 675 : rasain : rasain
# 676 : lo : lo
# 677 : nyesel : nyesel
# 678 : dwonload : dwonload
# 679 : gini : gin
# 680 : berkualitas : kualitas
# 681 : ntar : ntar
# 682 : nyeseljaringan : nyeseljaringan
# 683 : tanda : tanda
# 684 : ilang : ilang
# 685 : meningan : ning
# 686 : curi : curi
# 687 : linknya : linknya
# 688 : salin : salin
# 689 : lancarpokoknya : lancarpokoknya
# 690 : inipayah : inipayah
# 691 : satunya : satu
# 692 : seakan : akan
# 693 : tawarkan : tawar
# 694 : tulisannya : tulis
# 695 : loh : loh
# 696 : mulumau : mulumau
# 697 : secepatnya : cepat
# 698 : super : super
# 699 : terindeks : indeks
# 700 : penelusuran : telusur
# 701 : google : google
# 702 : peringkat : peringkat
# 703 : page : page
# 704 : padalah : pada
# 705 : kuat : kuat
# 706 : nyambunya : nyambunya
# 707 : bagusmasa : bagusmasa
# 708 : motogp : motogp
# 709 : katanyabisa : katanyabisa
# 710 : channeljgn : channeljgn
# 711 : bohong : bohong
# 712 : nich : nich
# 713 : aplikasintn : aplikasintn
# 714 : kesayangan : sayang
# 715 : dimanapun : mana
# 716 : grace : grace
# 717 : natalie : natalie
# 718 : selebihnya : lebih
# 719 : dechtks : dechtks
# 720 : lumayanlahmasih : lumayanlahmasih
# 721 : chanelchanelnya : chanelchanelnya
# 722 : chanelchanel : chanelchanel
# 723 : fox : fox
# 724 : grup : grup
# 725 : acak : acak
# 726 : siarannya : siar
# 727 : terbatasnya : batas
# 728 : akibat : akibat
# 729 : lainya : lai
# 730 : dinaikan : naik
# 731 : transisi : transisi
# 732 : pindah : pindah
# 733 : gaperlu : gaperlu
# 734 : dlu : dlu
# 735 : dr : dr
# 736 : lngsung : lngsung
# 737 : pilihan : pilih
# 738 : topup : topup
# 739 : ketuk : ketuk
# 740 : diatas : atas
# 741 : repot : repot
# 742 : gontaganti : gontaganti
# 743 : opsi : opsi
# 744 : pembayaran : bayar
# 745 : potong : potong
# 746 : pulsa : pulsa
# 747 : atw : atw
# 748 : harga : harga
# 749 : mahalin : mahalin
# 750 : hooq : hooq
# 751 : transfer : transfer
# 752 : bank : bank
# 753 : dana : dana
# 754 : kartu : kartu
# 755 : kredit : kredit
# 756 : buktinya : bukti
# 757 : padahalkan : padahal
# 758 : lihatnys : lihatnys
# 759 : kerja : kerja
# 760 : terkait : kait
# 761 : transmedia : transmedia
# 762 : apalah : apa
# 763 : ngerti : ngerti
# 764 : ngeloading : ngeloading
# 765 : jengkel : jengkel
# 766 : trus : trus
# 767 : beinsport : beinsport
# 768 : suaranya : suara
# 769 : informasinya : informasi
# 770 : partai : partai
# 771 : psi : psi
# 772 : hilangkan : hilang
# 773 : ane : ane
# 774 : enek : enek
# 775 : lht : lht
# 776 : nyeklo : nyeklo
# 777 : doain : doain
# 778 : pemilik : milik
# 779 : pembuat : buat
# 780 : hidayah : hidayah
# 781 : uang : uang
# 782 : halalaamiin : halalaamiin
# 783 : mengubah : ubah
# 784 : nama : nama
# 785 : username : username
# 786 : kesalahan : salah
# 787 : memasukan : pasu
# 788 : kedaftar : daftar
# 789 : dongkol : dongkol
# 790 : gka : gka
# 791 : edit : edit
# 792 : akunnya : akun
# 793 : mendingan : mending
# 794 : ketimbang : ketimbang
# 795 : lemotnya : lot
# 796 : parah : parah
# 797 : muteeeeerr : muteeeeerr
# 798 : g : g
# 799 : ngaruh : ngaruh
# 800 : taik : taik
# 801 : mobile : mobile
# 802 : berlanganan : berlanganan
# 803 : murah : murah
# 804 : meriah : riah
# 805 : buangin : buangin
# 806 : mengunakan : mengunakan
# 807 : kepentingan : penting
# 808 : sebetul : betul
# 809 : mengandung : kandung
# 810 : kekurangan : kurang
# 811 : bosen : bosen
# 812 : menunggu : tunggu
# 813 : signalnya : signalnya
# 814 : lola : lola
# 815 : kecewaaa : kecewaaa
# 816 : beratttt : beratttt
# 817 : batasi : batas
# 818 : satelit : satelit
# 819 : nasional : nasional
# 820 : replay : replay
# 821 : dihapus : hapus
# 822 : veli : veli
# 823 : premium : premium
# 824 : auto : auto
# 825 : mlem : mlem
# 826 : skrg : skrg
# 827 : bisaudah : bisaudah
# 828 : ttep : ttep
# 829 : bisaselalu : bisaselalu
# 830 : andatlong : andatlong
# 831 : trmkasi : trmkasi
# 832 : texs : texs
# 833 : ngomong : ngomong
# 834 : banyk : banyk
# 835 : drama : drama
# 836 : paham : paham
# 837 : omongan : omong
# 838 : pembincarannya : pembincarannya
# 839 : kesimpulannya : simpul
# 840 : texst : texst
# 841 : bibirnya : bibir
# 842 : gituh : gituh
# 843 : nyacuman : nyacuman
# 844 : kualitasnya : kualitas
# 845 : kuranglemot : kuranglemot
# 846 : diperbaikiiiiii : diperbaikiiiiii
# 847 : pengen : ken
# 848 : tvri : tvri
# 849 : daerah : daerah
# 850 : ja : ja
# 851 : guys : guys
# 852 : msk : msk
# 853 : lgsg : lgsg
# 854 : livetapi : livetapi
# 855 : resolusinya : resolusi
# 856 : bagusauto : bagusauto
# 857 : ketinggalan : tinggal
# 858 : dulubaru : dulubaru
# 859 : masak : masak
# 860 : enak : enak
# 861 : suruh : suruh
# 862 : memperbaharuipdahal : memperbaharuipdahal
# 863 : dpat : dpat
# 864 : mnit : mnit
# 865 : periksa : periksa
# 866 : inisangat : inisangat
# 867 : memuas : muas
# 868 : membatu : batu
# 869 : listrik : listrik
# 870 : kampung : kampung
# 871 : kebingungan : bingung
# 872 : nggak : nggak
# 873 : tunggu : tunggu
# 874 : didownload : didownload
# 875 : aktifkan : aktif
# 876 : deskripsi : deskripsi
# 877 : ditulis : tulis
# 878 : tipu : tipu
# 879 : pt : pt
# 880 : kreatif : kreatif
# 881 : media : media
# 882 : karya : karya
# 883 : bintangnya : bintang
# 884 : diturunkan : turun
# 885 : jadwalnya : jadwal
# 886 : tulisan : tulis
# 887 : can : can
# 888 : still : still
# 889 : watch : watch
# 890 : desktop : desktop
# 891 : version : version
# 892 : mencoba : coba
# 893 : days : days
# 894 : rencananya : rencana
# 895 : eehh : eehh
# 896 : tertarik : tarik
# 897 : benarkan : benar
# 898 : salam : salam
# 899 : olahraga : olahraga
# 900 : sepak : sepak
# 901 : real : real
# 902 : madrid : madrid
# 903 : abalabal : abalabal
# 904 : mind : mind
# 905 : sensor : sensor
# 906 : kagak : kagak
# 907 : duit : duit
# 908 : utk : utk
# 909 : pajak : pajak
# 910 : untung : untung
# 911 : afa : afa
# 912 : otak : otak
# 913 : elu : elu
# 914 : smentara : smentara
# 915 : kepuasan : puas
# 916 : pelanggan : langgan
# 917 : pikirin : pikirin
# 918 : jam : jam
# 919 : awas : awas
# 920 : macetmacetan : macetmacetan
# 921 : bingit : bingit
# 922 : spam : spam
# 923 : original : original
# 924 : konformasinya : konformasinya
# 925 : trima : trima
# 926 : no : no
# 927 : isat : isat
# 928 : kecepatan : cepat
# 929 : ampe : ampe
# 930 : mbs : mbs
# 931 : ditambah : tambah
# 932 : sedangkam : sedangkam
# 933 : boros : boros
# 934 : negara : negara
# 935 : terpercaya : percaya
# 936 : sajian : saji
# 937 : bersih : bersih
# 938 : penerimaan : terima
# 939 : kekuatan : kuat
# 940 : menikmati : nikmat
# 941 : admin : admin
# 942 : kucari : cari
# 943 : cari : cari
# 944 : ketemu : ketemu
# 945 : kusukai : suka
# 946 : ngelaklive : ngelaklive
# 947 : streamingdan : streamingdan
# 948 : sukalah : suka
# 949 : aplikasihnya : aplikasihnya
# 950 : streiming : streiming
# 951 : saran : saran
# 952 : laporan : lapor
# 953 : gampang : gampang
# 954 : mimin : mimin
# 955 : benahi : benah
# 956 : eror : eror
# 957 : subnya : sub
# 958 : audionya : audio
# 959 : reguler : reguler
# 960 : gaptek : gaptek
# 961 : kakak : kakak
# 962 : sekian : sekian
# 963 : iflix : iflix
# 964 : gaes : gaes
# 965 : free : free
# 966 : vip : vip
# 967 : menurutku : turut
# 968 : lainnyatolong : lainnyatolong
# 969 : kualitasnyakarena : kualitasnyakarena
# 970 : terbaik : baik
# 971 : bsa : bsa
# 972 : ngetik : ngetik
# 973 : pencarian : cari
# 974 : ketik : ketik
# 975 : kmbali : kmbali
# 976 : menu : menu
# 977 : gmna : gmna
# 978 : cra : cra
# 979 : tnton : tnton
# 980 : ngangu : ngangu
# 981 : gimana : gimana
# 982 : kebuka : buka
# 983 : nyaman : nyaman
# 984 : dimiliki : milik
# 985 : initolong : initolong
# 986 : didalamnyasepertiakses : didalamnyasepertiakses
# 987 : belom : bom
# 988 : tonton : tonton
# 989 : kejujurannya : jujur
# 990 : tertipu : tipu
# 991 : notifikasi : notifikasi
# 992 : aktifin : aktifin
# 993 : balikin : balikin
# 994 : keeren : keeren
# 995 : terang : terang
# 996 : inicmn : inicmn
# 997 : disinj : disinj
# 998 : perbarui : baru
# 999 : perbaikin : perbaikin
# 1000 : gagal : gagal
# 1001 : status : status
# 1002 : sucsess : sucsess
# 1003 : terupload : terupload
# 1004 : system : system
# 1005 : uploadnya : uploadnya
# 1006 : inikarna : inikarna
# 1007 : menonton : tonton
# 1008 : bisatop : bisatop
# 1009 : bangat : bangat
# 1010 : gitulahaplikasinya : gitulahaplikasinya
# 1011 : membantutp : membantutp
# 1012 : q : q
# 1013 : byk : byk
# 1014 : iklandan : iklandan
# 1015 : favorit : favorit
# 1016 : bbrp : bbrp
# 1017 : hilangcontoh : hilangcontoh
# 1018 : ky : ky
# 1019 : ganteng : ganteng
# 1020 : srigala : srigala
# 1021 : pdhl : pdhl
# 1022 : msih : msih
# 1023 : minatnya : minat
# 1024 : hya : hya
# 1025 : lengkaptolong : lengkaptolong
# 1026 : diperbaikithanks : diperbaikithanks
# 1027 : sngat : sngat
# 1028 : bgtu : bgtu
# 1029 : snng : snng
# 1030 : dngan : dngan
# 1031 : adnya : adnya
# 1032 : mna : mna
# 1033 : ucpkan : ucpkan
# 1034 : trimah : trimah
# 1035 : lupa : lupa
# 1036 : cinta : cinta
# 1037 : suci : suci
# 1038 : oky : oky
# 1039 : terlambat : lambat
# 1040 : dri : dri
# 1041 : bbm : bbm
# 1042 : stabil : stabil
# 1043 : dannsiaran : dannsiaran
# 1044 : dech : dech
# 1045 : memikir : pikir
# 1046 : keuntungan : untung
# 1047 : menjual : jual
# 1048 : konsumen : konsumen
# 1049 : serentak : serentak
# 1050 : terlmbat : terlmbat
# 1051 : pda : pda
# 1052 : buatan : buat
# 1053 : mikirkan : mikirkan
# 1054 : dompet : dompet
# 1055 : sndri : sndri
# 1056 : pertahankan : tahan
# 1057 : pertahankn : pertahankn
# 1058 : laporkan : lapor
# 1059 : penipuan : tipu
# 1060 : menyimpan : simpan
# 1061 : offline : offline
# 1062 : peningkatan : tingkat
# 1063 : putus : putus
# 1064 : perbaikkan : baik
# 1065 : mendownload : mendownload
# 1066 : apah : apah
# 1067 : memperbaiki : baik
# 1068 : dalan : dal
# 1069 : makan : makan
# 1070 : bolapun : bola
# 1071 : smartpone : smartpone
# 1072 : astaga : astaga
# 1073 : sihhh : sihhh
# 1074 : tayangnya : tayang
# 1075 : disamain : disamain
# 1076 : menitt : menitt
# 1077 : alias : alias
# 1078 : adakannya : adakan
# 1079 : malaysia : malaysia
# 1080 : mata : mata
# 1081 : ringgit : ringgit
# 1082 : terkendala : kendala
# 1083 : membayar : bayar
# 1084 : maafapk : maafapk
# 1085 : diplay : diplay
# 1086 : seterusnyasering : seterusnyasering
# 1087 : memutar : putar
# 1088 : kwan : kwan
# 1089 : putusputus : putusputus
# 1090 : jaringannya : jaring
# 1091 : terrrrrima : terrrrrima
# 1092 : membuatkan : buat
# 1093 : berkaya : kaya
# 1094 : berdoa : doa
# 1095 : job : job
# 1096 : kecuali : kecuali
# 1097 : introveksi : introveksi
# 1098 : sayang : sayang
# 1099 : salah : salah
# 1100 : melihay : melihay
# 1101 : acaranya : acara
# 1102 : slalu : slalu
# 1103 : bilang : bilang
# 1104 : komplain : komplain
# 1105 : tandanya : tanda
# 1106 : knpa : knpa
# 1107 : bintangkalo : bintangkalo
# 1108 : dsn : dsn
# 1109 : streming : streming
# 1110 : nyatpi : nyatpi
# 1111 : perbesar : besar
# 1112 : adakan : adakan
# 1113 : downloadnonton : downloadnonton
# 1114 : memiliki : milik
# 1115 : siang : siang
# 1116 : tipis : tipis
# 1117 : midnightnya : midnightnya
# 1118 : down : down
# 1119 : besok : besok
# 1120 : siangnya : siang
# 1121 : iklannya : iklan
# 1122 : stuck : stuck
# 1123 : kelar : kelar
# 1124 : kudu : kudu
# 1125 : reload : reload
# 1126 : servernya : servernya
# 1127 : ngelagngelag : ngelagngelag
# 1128 : internet : internet
# 1129 : belajar : ajar
# 1130 : maxstream : maxstream
# 1131 : ratusan : ratus
# 1132 : ribu : ribu
# 1133 : stream : stream
# 1134 : ngelag : ngelag
# 1135 : videomax : videomax
# 1136 : terkurang : kurang
# 1137 : flash : flash
# 1138 : gwe : gwe
# 1139 : masmba : masmba
# 1140 : browser : browser
# 1141 : bela : bela
# 1142 : belain : bain
# 1143 : persib : persib
# 1144 : rugi : rugi
# 1145 : dowload : dowload
# 1146 : persiapkan : siap
# 1147 : tuk : tuk
# 1148 : registrasi : registrasi
# 1149 : kerena : rena
# 1150 : mencobanya : coba
# 1151 : splikasinyanya : splikasinyanya
# 1152 : tersimpan : simpan
# 1153 : perbaikan : baik
# 1154 : berbayar : bayar
# 1155 : disruh : disruh
# 1156 : emg : emg
# 1157 : org : org
# 1158 : kalangan : kalang
# 1159 : numpang : numpang
# 1160 : orangini : orangini
# 1161 : lho : lho
# 1162 : hiburan : hibur
# 1163 : rakyat : rakyat
# 1164 : surh : surh
# 1165 : kt : kt
# 1166 : yaudahlah : yaudahlah
# 1167 : empunya : empunya
# 1168 : analog : analog
# 1169 : semutan : semut
# 1170 : hati : hati
# 1171 : apus : apus
# 1172 : penguna : penguna
# 1173 : sms : sms
# 1174 : atuo : atuo
# 1175 : stop : stop
# 1176 : kluar : kluar
# 1177 : it : it
# 1178 : suck : suck
# 1179 : bolak : bolak
# 1180 : hancur : hancur
# 1181 : tontomketerangan : tontomketerangan
# 1182 : nyaoops : nyaoops
# 1183 : kmu : kmu
# 1184 : kawatir : kawatir
# 1185 : nyamaksud : nyamaksud
# 1186 : canel : canel
# 1187 : nih : nih
# 1188 : axn : axn
# 1189 : animax : animax
# 1190 : coming : coming
# 1191 : soon : soon
# 1192 : tibatiba : tibatiba
# 1193 : premiernya : premiernya
# 1194 : national : national
# 1195 : geographics : geographics
# 1196 : cartoon : cartoon
# 1197 : network : network
# 1198 : ituitu : ituitu
# 1199 : mempersulit : sulit
# 1200 : matsudnya : matsudnya
# 1201 : indonesi : indonesi
# 1202 : memenag : memenag
# 1203 : bayak : bayak
# 1204 : gunanya : guna
# 1205 : dimna : dimna
# 1206 : mobil : mobil
# 1207 : kegunann : kegunann
# 1208 : baca : baca
# 1209 : defolover : defolover
# 1210 : kenceng : kenceng
# 1211 : tanggapi : tanggap
# 1212 : lan : lan
# 1213 : jut : jut
# 1214 : sihpadahal : sihpadahal
# 1215 : jga : jga
# 1216 : banyaktapi : banyaktapi
# 1217 : bangetmohon : bangetmohon
# 1218 : telepisi : tepis
# 1219 : kemarinkemarin : kemarinkemarin
# 1220 : kesini : kesini
# 1221 : pakek : pakek
# 1222 : ngomongin : ngomongin
# 1223 : spek : spek
# 1224 : ukurannya : ukur
# 1225 : jelekmasa : jelekmasa
# 1226 : dulugak : dulugak
# 1227 : tinggal : tinggal
# 1228 : ajajadi : ajajadi
# 1229 : gue : gue
# 1230 : hnya : hnya
# 1231 : mlh : mlh
# 1232 : kgk : kgk
# 1233 : pdahal : pdahal
# 1234 : volume : volume
# 1235 : fullin : fullin
# 1236 : sulit : sulit
# 1237 : connect : connect
# 1238 : contoh : contoh
# 1239 : maxtrem : maxtrem
# 1240 : telkomsel : telkomsel
# 1241 : kalu : kalu
# 1242 : macetnya : macet
# 1243 : appnya : appnya
# 1244 : simpan : simpan
# 1245 : nunggu : nunggu
# 1246 : klu : klu
# 1247 : rencana : rencana
# 1248 : appk : appk
# 1249 : final : final
# 1250 : europa : europa
# 1251 : league : league
# 1252 : krena : krena
# 1253 : disensor : sensor
# 1254 : giliran : gilir
# 1255 : tetp : tetp
# 1256 : maketin : maketin
# 1257 : kcewa : kcewa
# 1258 : kena : kena
# 1259 : paketan : paket
# 1260 : perkecil : kecil
# 1261 : size : size
# 1262 : videonyaterus : videonyaterus
# 1263 : ngasih : ngasih
# 1264 : disetiap : tiap
# 1265 : halaman : halaman
# 1266 : dirubah : rubah
# 1267 : parabola : parabola
# 1673 : bisakecewa : bisakecewa
# 1674 : yak : yak
# 1675 : terjaditerima : terjaditerima
# 1676 : menayangkan : tayang
# 1677 : sdah : sdah
# 1678 : bru : bru
# 1679 : kejadian : jadi
# 1680 : kick : kick
# 1681 : off : off
# 1682 : sajaapalagi : sajaapalagi
# 1683 : sibuk : sibuk
# 1684 : kerjajadi : kerjajadi
# 1685 : ninton : ninton
# 1686 : tvterimakasih : tvterimakasih
# 1687 : upgrade : upgrade
# 1688 : layanan : layan
# 1689 : isi : isi
# 1690 : pemium : pemium
# 1691 : pertanggung : tanggung
# 1692 : jawabannya : jawab
# 1693 : pertalite : pertalite
# 1694 : pertamax : pertamax
# 1695 : lagiresponnya : lagiresponnya
# 1696 : nontonudah : nontonudah
# 1697 : modal : modal
# 1698 : gi : gi
# 1699 : kek : kek
# 1700 : piki : piki
# 1701 : kasian : kasi
# 1702 : emng : emng
# 1703 : perubahan : ubah
# 1704 : copot : copot
# 1705 : kemudahan : mudah
# 1706 : channell : channell
# 1707 : celah : celah
# 1708 : dibawah : bawah
# 1709 : berisi : isi
# 1710 : iklansetiap : iklansetiap
# 1711 : kedipberisi : kedipberisi
# 1712 : virus : virus
# 1713 : halah : halah
# 1714 : eps : eps
# 1715 : judulnya : judul
# 1716 : cm : cm
# 1717 : sebentar : sebentar
# 1718 : filmnya : film
# 1719 : dipencarian : cari
# 1720 : berlangganantidak : berlangganantidak
# 1721 : bolamohon : bolamohon
# 1722 : perbaikilahmaksih : perbaikilahmaksih
# 1723 : semonga : semonga
# 1724 : berlanggananbiar : berlanggananbiar
# 1725 : bangga : bangga
# 1726 : perminggu : minggu
# 1727 : menyaksikan : saksi
# 1728 : dlltapi : dlltapi
# 1729 : mguitu : mguitu
# 1730 : belaka : belaka
# 1731 : diandroid : diandroid
# 1732 : maksimalhanya : maksimalhanya
# 1733 : dibukafitur : dibukafitur
# 1734 : dibukadng : dibukadng
# 1735 : menanggapitlng : menanggapitlng
# 1736 : premiewr : premiewr
# 1737 : diperpanjang : panjang
# 1738 : pemberitahuan : pemberitahuan
# 1739 : sungguh : sungguh
# 1740 : dzolim : dzolim
# 1741 : masukkan : masuk
# 1742 : kerjasama : kerjasama
# 1743 : operator : operator
# 1744 : bebaskan : bebas
# 1745 : tarif : tarif
# 1746 : datanya : data
# 1747 : alplikasi : alplikasi
# 1748 : signal : signal
# 1749 : pencinta : cinta
# 1750 : yotube : yotube
# 1751 : sajaa : sajaa
# 1752 : segi : segi
# 1753 : gambara : gambara
# 1754 : kuantitas : kuantitas
# 1755 : benci : benci
# 1756 : inii : ini
# 1757 : pembayatsn : pembayatsn
# 1758 : payaaah : payaaah
# 1759 : apknya : apknya
# 1760 : hilangin : hilangin
# 1761 : mewakilkan : wakil
# 1762 : sependapat : dapat
# 1763 : kebanggaan : bangga
# 1764 : bertanding : tanding
# 1765 : dipermudahkan : mudah
# 1766 : notabe : notabe
# 1767 : menyiarkan : siar
# 1768 : php : php
# 1769 : buang : buang
# 1770 : kawan : kawan
# 1771 : kesal : kesal
# 1983 : banged : banged
# 1984 : cocok : cocok
# 1985 : inidripada : inidripada
# 1986 : dpt : dpt
# 1987 : trouble : trouble
# 1988 : terusmodal : terusmodal
# 1989 : abis : abis
# 1990 : sinyaly : sinyaly
# 1991 : gan : gan
# 1992 : nntony : nntony
# 1993 : keputus : putus
# 1994 : nnti : nnti
# 1995 : rubah : rubah
# 1996 : bintangy : bintangy
# 1997 : yahh : yahh
# 1998 : dowbload : dowbload
# 1999 : pemasukan : pasu
# 2000 : delete : delete
# 2001 : livestream : livestream
# 2002 : apaapa : apaapa
# 2003 : berlanggan : langgan
# 2004 : kelewatan : lewat
# 2005 : jdinya : jdinya
# 2006 : enjoyyy : enjoyyy
# 2007 : daun : daun
# 2008 : tamba : tamba
# 2009 : donwlodx : donwlodx
# 2010 : habisin : habisin
# 2011 : diacakmending : diacakmending
# 2012 : kaga : kaga
# 2013 : donwlod : donwlod
# 2014 : yaaa : yaaa
# 2015 : disitu : situ
# 2016 : ishq : ishq
# 2017 : mein : mein
# 2018 : marjawan : marjawan
# 2019 : ditanggapi : tanggap
# 2020 : jedanya : jeda
# 2021 : truss : truss
# 2022 : jdi : jdi
# 2023 : nontonnya : nontonnya
# 2024 : dipake : dipake
# 2025 : dpake : dpake
# 2026 : ular : ular
# 2027 : ngejar : ngejar
# 2028 : ekornya : ekor
# 2029 : pakeh : pakeh
# 2030 : sampek : sampek
# 2031 : terkuras : kuras
# 2032 : delima : delima
# 2033 : higligtnya : higligtnya
# 2034 : sekrinshoot : sekrinshoot
# 2035 : tengs : tengs
# 2036 : aplnya : aplnya
# 2037 : diharapkan : harap
# 2038 : berita : berita
# 2039 : lbh : lbh
# 2040 : bingung : bingung
# 2041 : supir : supir
# 2042 : majikan : majikan
# 2043 : adamenghilang : adamenghilang
# 2044 : fullnya : fullnya
# 2045 : penasaran : penasaran
# 2046 : sekarnag : sekarnag
# 2047 : sinetronnya : sinetron
# 2048 : asalan : asal
# 2049 : dikurangi : rang
# 2050 : habisnya : habis
# 2051 : diupdate : diupdate
# 2052 : mikir : mikir
# 2053 : ups : ups
# 2054 : keceplosan : ceplos
# 2055 : mode : mode
# 2056 : global : global
# 2057 : komplin : komplin
# 2058 : membawa : bawa
# 2059 : hasil : hasil
# 2060 : tambai : tambai
# 2061 : psti : psti
# 2062 : gangguanmsa : gangguanmsa
# 2063 : gpp : gpp
# 2064 : pokonya : poko
# 2065 : nyetel : nyetel
# 2066 : ngeplay : ngeplay
# 2067 : refresh : refresh
# 2068 : streeming : streeming
# 2069 : assuuu : assuuu
# 2070 : cantum : cantum
# ...
# 16931 : bangeeeetttt : bangeeeetttt
# 16932 : privasi : privasi
# 16933 : sematkan : semat
# 16934 : snippet : snippet
# 16935 : disalin : salin
# 16936 : kedaluwarsa : kedaluwarsa
# 16937 : jamanda : jamanda
# 16938 : klip : klip
# 16939 : atasanda : atasanda
# 16940 : dapatgeser : dapatgeser
# 16941 : menghapusnyaanda : menghapusnyaanda
# 16942 : atasgeser : atasgeser
# 16943 : menghapusnyateks : menghapusnyateks
# 16944 : ditam : tam
# 16945 : bgtmau : bgtmau
# 16946 : bayang : bayang
# 16947 : berlangganansetiap : berlangganansetiap
# 16948 : wkkwkwwk : wkkwkwwk
# 16949 : udahbeli : udahbeli
# 16950 : tazza : tazza
# 16951 : ngambi : ngambi
# 16952 : lambatt : lambatt
# 16953 : pesen : sen
# 16954 : dibandingi : banding
# 16955 : bioskopsipmantaplahokey : bioskopsipmantaplahokey
# 16956 : tebaktebakan : tebaktebakan
# 16957 : taiiikk : taiiikk
# 16958 : biasnya : bias
# 16959 : maratonkrna : maratonkrna
# 16960 : ngelagbufferingpadahal : ngelagbufferingpadahal
# 16961 : penuhmau : penuhmau
# 16962 : iklanjangan : iklanjangan
# 16963 : nyague : nyague
# 16964 : disinibukan : sibuk
# 16965 : iklankebuang : iklankebuang
# 16966 : terobos : terobos
# 16967 : perampok : rampok
# 16968 : bagusmantaaap : bagusmantaaap
# 16969 : malahn : malahn
# 16970 : putarr : putarr
# 16971 : kesalahn : kesalahn
# 16972 : outar : outar
# 16973 : bagut : bagut
# 16974 : lemotloading : lemotloading
# 16975 : bandung : bandung
# 16976 : standby : standby
# 16977 : ajandak : ajandak
# 16978 : gejala : gejala
# 16979 : ngefrezee : ngefrezee
# 16980 : filman : film
# 16981 : nyentuh : nyentuh
# 16982 : surgamu : surga
# 16983 : duitannya : duit
# 16984 : gojek : gojek
# 16985 : sepengetauan : tau
# 16986 : mnpecialkan : mnpecialkan
# 16987 : acr : acr
# 16988 : ktika : ktika
# 16989 : livoli : livoli
# 16990 : tyangkan : tyangkan
# 16991 : trlewatkan : trlewatkan
# 16992 : poke : poke
# 16993 : konoha : konoha
# 16994 : downy : downy
# 16995 : grade : grade
# 16996 : kuningan : kuningan
# 16997 : ganga : ganga
# 16998 : mujhse : mujhse
# 16999 : dosti : dosti
# 17000 : karoge : karoge
# 17001 : visualnya : visual
# 17002 : mencakup : cakup
# 17003 : bagussebanernya : bagussebanernya
# 17004 : iklanmembosan : iklanmembosan
# 17005 : sumbangan : sumbang
# 17006 : ndet : ndet
# 17007 : detan : detan
# 17008 : kwoontoolll : kwoontoolll
# 17009 : fullterus : fullterus
# 17010 : gabisaaa : gabisaaa
# 17011 : tanyan : tanyan
# 17012 : dolot : dolot
# 17013 : gaa : gaa
# 17014 : bukaampuncoba : bukaampuncoba
# 17015 : ngenakin : ngenakin
# 17016 : paralel : paralel
# 17017 : updat : updat
# 17018 : konvensional : konvensional
# 17019 : minudh : minudh
# 17020 : euyy : euyy
# 17021 : ganjar : ganjar
# 17022 : mahfud : mahfud
# 17023 : wepunya : wepunya
# 17024 : pdi : pdi
# 17025 : lengkapib : lengkapib
# 17026 : nyak : nyak
# 17027 : dongkalau : dongkalau
# 17028 : kelanjutanmasa : kelanjutanmasa
# 17029 : pepek : pepek
# 17030 : kalopun : kalo
# 17031 : hrusnya : hrusnya
# 17032 : delain : delain
# 17033 : jwabanya : jwabanya
# 17034 : jatingan : jatingan
# 17035 : bugis : bugis
# 17036 : mnampilkan : mnampilkan
# 17037 : bannget : bannget
# 17038 : setiapa : setiapa
# 17039 : eplnya : eplnya
# 17040 : frez : frez
# 17041 : masif : masif
# 17042 : filmfilmnya : filmfilmnya
# 17043 : huhuuu : huhuuu
# 17044 : lang : lang
# 17045 : sung : sung
# 17046 : singgung : singgung
# 17047 : ganggung : ganggung
# 17048 : sikit : sikit
# 17049 : lnsng : lnsng
# 17050 : sunlight : sunlight
# 17051 : nth : nth
# 17052 : sistemny : sistemny
# 17053 : xlknp : xlknp
# 17054 : lazio : lazio
# 17055 : doankyg : doankyg
# 17056 : mission : mission
# 17057 : ses : ses
# 17058 : wahhhh : wahhhh
# 17059 : hoiii : hoiii
# 17060 : tennis : tennis
# 17061 : devnya : devnya
# 17062 : dunkirk : dunkirk
# 17063 : castle : castle
# 17064 : konosuba : konosuba
# 17065 : devil : devil
# 17066 : timer : timer
# 17067 : erorterussss : erorterussss
# 17068 : aaya : aaya
# 17069 : bnnyak : bnnyak
# 17070 : meleebihi : meleebihi
# 17071 : berlipat : lipat
# 17072 : updatebanyak : updatebanyak
# 17073 : ekspress : ekspress
# 17074 : jgaaa : jgaaa
# 17075 : soan : soan
# 17076 : batu : batu
# 17077 : last : last
# 17078 : aot : aot
# 17079 : demon : demon
# 17080 : slayer : slayer
# 17081 : ooh : ooh
# 17082 : muterin : muterin
# 17083 : bgm : bgm
# 17084 : tot : tot
# 17085 : buseeet : buseeet
# 17086 : lvideo : lvideo
# 17087 : penipugw : penipugw
# 17088 : axistapi : axistapi
# 17089 : duluakun : duluakun
# 17090 : paok : paok
# 17091 : bodong : bodong
# 17092 : ll : ll
# 17093 : langsunggagal : langsunggagal
# 17094 : hebatnya : hebat
# 17095 : almost : almost
# 17096 : dijumpai : jumpa
# 17097 : menolak : tolak
# 17098 : merta : merta
# 17099 : sampahhh : sampahhh
# 17100 : sampahh : sampahh
# 17101 : iklanbaru : iklanbaru
# 17102 : uin : uin
# 17103 : jambi : jambi
# 17104 : dongmasa : dongmasa
# 17105 : iklannyamohon : iklannyamohon
# 17106 : pembalikan : balik
# 17107 : ditvdan : ditvdan
# 17108 : sampaidetik : sampaidetik
# 17109 : sumpahmnyebalkan : sumpahmnyebalkan
# 17110 : biasahhhhhhh : biasahhhhhhh
# 17111 : extraa : extraa
# 17112 : anakku : anak
# 17113 : dewasanya : dewasa
# 17114 : pengawasan : awas
# 17115 : sembarangan : sembarang
# 17116 : menitanditv : menitanditv
# 17117 : gocek : gocek
# 17118 : dorama : dorama
# 17119 : tanduk : tanduk
# 17120 : kurangikarena : kurangikarena
# 17121 : patahbayar : patahbayar
# 17122 : ajejd : ajejd
# 17123 : berproses : proses
# 17124 : andasekarang : andasekarang
# 17125 : prangkat : prangkat
# 17126 : ovoku : ovoku
# 17127 : njeng : njeng
# 17128 : glicth : glicth
# 17129 : siarang : siarang
# 17130 : ngeleqan : ngeleqan
# 17131 : kakcara : kakcara
# 17132 : berukuran : ukur
# 17133 : berlangganankok : berlangganankok
# 17321 : platinumada : platinumada
# 17322 : leaguetp : leaguetp
# 17323 : penawaranya : penawaranya
# 17324 : terbaiklah : baik
# 17325 : segaban : segaban
# 17326 : menindaklanjuti : menindaklanjuti
# 17327 : berbasis : bas
# 17328 : isiny : isiny
# 17329 : underrated : underrated
# 17330 : pengabdi : abdi
# 17331 : hahahaa : hahahaa
# 17332 : sendirj : sendirj
# 17333 : eunha : eunha
# 17334 : exweaponnya : exweaponnya
# 17335 : priscilla : priscilla
# 17336 : clara : clara
# 17337 : guardian : guardian
# 17338 : tales : tales
# 17339 : kong : kong
# 17340 : biznet : biznet
# 17341 : keceng : keceng
# 17342 : gakpapa : gakpapa
# 17343 : bangetdah : bangetdah
# 17344 : nyesaaal : nyesaaal
# 17345 : pakeettt : pakeettt
# 17346 : huufftttt : huufftttt
# 17347 : babus : babus
# 17348 : nomber : nomber
# 17349 : burnley : burnley
# 17350 : putarjuga : putarjuga
# 17351 : terbarulama : terbarulama
# 17352 : kpanjangan : kpanjangan
# 17353 : panda : panda
# 17354 : bocil : bocil
# 17355 : kacauuubeli : kacauuubeli
# 17356 : trspadahal : trspadahal
# 17357 : gajels : gajels
# 17358 : tololllltapi : tololllltapi
# 17359 : sedian : dian
# 17360 : konfirm : konfirm
# 17361 : novemberbulan : novemberbulan
# 17362 : minmohon : minmohon
# 17363 : apaanbaru : apaanbaru
# 17364 : ajag : ajag
# 17365 : look : look
# 17366 : lokga : lokga
# 17367 : solved : solved
# 17368 : uanglangganan : uanglangganan
# 17369 : suzume : suzume
# 17370 : tojimari : tojimari
# 17371 : nyasdh : nyasdh
# 17372 : midnight : midnight
# 17373 : runner : runner
# 17374 : teriak : teriak
# 17375 : detikparah : detikparah
# {'sumpah': 'sumpah', 'aplikasi': 'aplikasi', 'bikin': 'bikin', 'gw': 'gw', 'kesel': 'kesel', 'udah': 'udah', 'hapus': 'hapus', 'trs': 'trs', 'download': 'download', 'ulang': 'ulang', 'aja': 'aja', 'ga': 'ga', 'dibuka': 'buka', 'buka': 'buka', 'munculnya': 'muncul', 'layar': 'layar', 'putih': 'putih', 'doang': 'doang', 'gatau': 'gatau', 'gada': 'gada', 'kendala': 'kendala', 'lumayan': 'lumayan', 'bagus': 'bagus', 'tolong': 'tolong', 'perbaiki': 'baik', 'gangguan': 'ganggu', 'nya': 'nya', 'channel': 'channel', 'putar': 'putar', 'banget': 'banget', 'lihat': 'lihat', 'tv': 'tv', 'dimn': 'dimn', 'bepergian': 'pergi', 'jarak': 'jarak', 'jauhdekat': 'jauhdekat', 'mati': 'mati', 'lampulistrik': 'lampulistrik', 'dlln': 'dlln', 'tampilkan': 'tampil', 'liga': 'liga', 'nntin': 'nntin', 'laliga': 'laliga', 'champion': 'champion', 'tpi': 'tpi', 'mala': 'mala', 'tdk': 'tdk', 'alasannya': 'alas', 'hak': 'hak', 'cipta': 'cipta', 'bayar': 'bayar', 'ka': 'ka', 'sda': 'sda', 'penggemar': 'gemar', 'pendapatan': 'dapat', 'jg': 'jg', 'bn
'min', 'fullscreen': 'fullscreen', 'miring': 'miring', 'sisi': 'sisi', 'otomatis': 'otomatis', 'nyala': 'nyala', 'app': 'app', 'tp': 'tp', 'knp': 'knp', 'stelah': 'stelah', 'd': 'd', 'update': 'update', 'loading': 'loading', 'y': 'y', 'sinyal': 'sinyal', 'sekalitolong': 'sekalitolong', 'pengguna': 'guna', 'solusinya': 'solusi', 'terimakasih': 'terimakasih', 'upload': 'upload', 'videononton': 'videononton', 'monetesi': 'monetesi', 'videojangan' ...
# ------------------------

# %%
#memisahkan file eksekusinya setelah pembacaaan term selesai
data_preproc['stemmed_content'] = data_preproc['tokenize_content'].apply(lambda x:' '.join(get_stemmed_term(x)))
data_preproc
# Out:
#                                                 content sentiment  \
# 0     Sumpah aplikasi ini bikin gw kesel sendiri. Ud...   Negatif
# 1     lumayan bagus tapi tolong di perbaiki gangguan...   Positif
# 2     Bagus banget Jadi bisa lihat TV dimn pun saat ...   Positif
# 3     Masa tidak bisa tampilkan semua liga, kami mau...   Negatif
# 4     Kayaknya aplikasi OONA lebih bagus, bagi yg ke...   Negatif
# ...                                                 ...       ...
# 9995  Aplikasi dari 2015 tapi film dan anime yang te...   Negatif
# 9996  Saya menyesal berlanggan vidio karena pembayar...   Negatif
# 9997  tolong apknya di update dong masa gak ada film...   Negatif
# 9998  masa nonton premier league vidionya lebih lamb...   Negatif
# 9999     Kurang bagus aplikasinya, terlalu banyak iklan   Negatif
#
#                                         cleaned_content  \
# 0     sumpah aplikasi ini bikin gw kesel sendiri uda...
# 1     lumayan bagus tapi tolong di perbaiki gangguan...
# 2     bagus banget jadi bisa lihat tv dimn pun saat ...
# 3     masa tidak bisa tampilkan semua liga kami mau ...
# 4     kayaknya aplikasi oona lebih bagus bagi yg kec...
# ...                                                 ...
# 9995  aplikasi dari  tapi film dan anime yang tersed...
# 9996  saya menyesal berlanggan vidio karena pembayar...
# 9997  tolong apknya di update dong masa gak ada film...
# 9998  masa nonton premier league vidionya lebih lamb...
# 9999      kurang bagus aplikasinya terlalu banyak iklan
#
#                               cleaned_content_stopwords  \
# 0     sumpah aplikasi bikin gw kesel udah gw hapus t...
# 1     lumayan bagus tolong perbaiki gangguan nya cha...
# 2     bagus banget lihat tv dimn bepergian jarak jau...
# 3     tampilkan liga nntin laliga liga champion tpi ...
# 4     kayaknya aplikasi oona bagus yg kecewa dgn apl...
# ...                                                 ...
# 9995  aplikasi film anime tersedia film anime tersed...
# 9996  menyesal berlanggan vidio pembayaran otomatis ...
# 9997      tolong apknya update gak film midnight runner
# 9998  nonton premier league vidionya lambat situs il...
# 9999                            bagus aplikasinya iklan
#
#                                        tokenize_content  \
# 0     [sumpah, aplikasi, bikin, gw, kesel, udah, gw,...
# 1     [lumayan, bagus, tolong, perbaiki, gangguan, n...
# 2     [bagus, banget, lihat, tv, dimn, bepergian, ja...
# 3     [tampilkan, liga, nntin, laliga, liga, champio...
# 4     [kayaknya, aplikasi, oona, bagus, yg, kecewa, ...
# ...                                                 ...
# 9995  [aplikasi, film, anime, tersedia, film, anime,...
# 9996  [menyesal, berlanggan, vidio, pembayaran, otom...
# 9997  [tolong, apknya, update, gak, film, midnight, ...
# 9998  [nonton, premier, league, vidionya, lambat, si...
# 9999                        [bagus, aplikasinya, iklan]
#
#                                        pos_tags_content  \
# 0     [(sumpah, NN), (aplikasi, NN), (bikin, FW), (g...
# 1     [(lumayan, NN), (bagus, JJ), (tolong, VB), (pe...
# 2     [(bagus, JJ), (banget, NN), (lihat, VB), (tv, ...
# 3     [(tampilkan, VB), (liga, CD), (nntin, NN), (la...
# 4     [(kayaknya, RB), (aplikasi, VB), (oona, NN), (...
# ...                                                 ...
# 9995  [(aplikasi, NN), (film, NN), (anime, NN), (ter...
# 9996  [(menyesal, NN), (berlanggan, NN), (vidio, NN)...
# 9997  [(tolong, VB), (apknya, RB), (update, FW), (ga...
# 9998  [(nonton, FW), (premier, FW), (league, FW), (v...
# 9999      [(bagus, JJ), (aplikasinya, RB), (iklan, VB)]
#
#                                         indexed_content  \
# 0     [sumpah, aplikasi, ulang, aja, ga, dibuka, buk...
# 1     [lumayan, bagus, tolong, perbaiki, gangguan, n...
# 2     [bagus, banget, lihat, tv, dimn, bepergian, ja...
# 3     [tampilkan, nntin, tpi, mala, tdk, alasannya, ...
# 4     [kayaknya, aplikasi, oona, bagus, yg, kecewa, ...
# ...                                                 ...
# 9995  [aplikasi, film, anime, tersedia, film, anime,...
# 9996  [menyesal, berlanggan, vidio, pembayaran, otom...
# 9997                                   [tolong, apknya]
# 9998  [vidionya, lambat, situs, ilegal, official, pa...
# 9999                        [bagus, aplikasinya, iklan]
#
#                                       lemmas_to_content  \
# 0     sumpah aplikasi ulang aja ga dibuka buka muncu...
# 1     lumayan bagus tolong perbaiki gangguan nya cha...
# 2     bagus banget lihat tv dimn bepergian jarak jau...
# 3     tampilkan nntin tpi mala tdk alasannya hak cip...
# 4     kayaknya aplikasi oona bagus yg kecewa dgn apl...
# ...                                                 ...
# 9995  aplikasi film anime tersedia film anime tersed...
# 9996  menyesal berlanggan vidio pembayaran otomatis ...
# 9997                                      tolong apknya
# 9998  vidionya lambat situs ilegal official partner ...
# 9999                            bagus aplikasinya iklan
#
#                                         stemmed_content
# 0     sumpah aplikasi bikin gw kesel udah gw hapus t...
# 1     lumayan bagus tolong baik ganggu nya channel p...
# 2     bagus banget lihat tv dimn pergi jarak jauhdek...
# 3     tampil liga nntin laliga liga champion tpi mal...
# 4     kayak aplikasi oona bagus yg kecewa dgn aplika...
# ...                                                 ...
# 9995  aplikasi film anime sedia film anime sedia apl...
# 9996  sesal langgan vidio bayar otomatis potong dana...
# 9997      tolong apknya update gak film midnight runner
# 9998  nonton premier league vidionya lambat situs il...
# 9999                               bagus aplikasi iklan
#
# [10000 rows x 9 columns]

# %%
# Ganti nilai 'Negatif' dengan 1 dan 'Positif' dengan 0 pada kolom 'sentiment'
data_preproc['sentiment'] = data_preproc['sentiment'].replace({'Negatif': 1, 'Positif': 0})

# Tampilkan hasil
data_preproc
# Out:
#                                                 content  sentiment  \
# 0     Sumpah aplikasi ini bikin gw kesel sendiri. Ud...          1
# 1     lumayan bagus tapi tolong di perbaiki gangguan...          0
# 2     Bagus banget Jadi bisa lihat TV dimn pun saat ...          0
# 3     Masa tidak bisa tampilkan semua liga, kami mau...          1
# 4     Kayaknya aplikasi OONA lebih bagus, bagi yg ke...          1
# ...                                                 ...        ...
# 9995  Aplikasi dari 2015 tapi film dan anime yang te...          1
# 9996  Saya menyesal berlanggan vidio karena pembayar...          1
# 9997  tolong apknya di update dong masa gak ada film...          1
# 9998  masa nonton premier league vidionya lebih lamb...          1
# 9999     Kurang bagus aplikasinya, terlalu banyak iklan          1
#
#                                         cleaned_content  \
# 0     sumpah aplikasi ini bikin gw kesel sendiri uda...
# 1     lumayan bagus tapi tolong di perbaiki gangguan...
# 2     bagus banget jadi bisa lihat tv dimn pun saat ...
# 3     masa tidak bisa tampilkan semua liga kami mau ...
# 4     kayaknya aplikasi oona lebih bagus bagi yg kec...
# ...                                                 ...
# 9995  aplikasi dari  tapi film dan anime yang tersed...
# 9996  saya menyesal berlanggan vidio karena pembayar...
# 9997  tolong apknya di update dong masa gak ada film...
# 9998  masa nonton premier league vidionya lebih lamb...
# 9999      kurang bagus aplikasinya terlalu banyak iklan
#
#                               cleaned_content_stopwords  \
# 0     sumpah aplikasi bikin gw kesel udah gw hapus t...
# 1     lumayan bagus tolong perbaiki gangguan nya cha...
# 2     bagus banget lihat tv dimn bepergian jarak jau...
# 3     tampilkan liga nntin laliga liga champion tpi ...
# 4     kayaknya aplikasi oona bagus yg kecewa dgn apl...
# ...                                                 ...
# 9995  aplikasi film anime tersedia film anime tersed...
# 9996  menyesal berlanggan vidio pembayaran otomatis ...
# 9997      tolong apknya update gak film midnight runner
# 9998  nonton premier league vidionya lambat situs il...
# 9999                            bagus aplikasinya iklan
#
#                                        tokenize_content  \
# 0     [sumpah, aplikasi, bikin, gw, kesel, udah, gw,...
# 1     [lumayan, bagus, tolong, perbaiki, gangguan, n...
# 2     [bagus, banget, lihat, tv, dimn, bepergian, ja...
# 3     [tampilkan, liga, nntin, laliga, liga, champio...
# 4     [kayaknya, aplikasi, oona, bagus, yg, kecewa, ...
# ...                                                 ...
# 9995  [aplikasi, film, anime, tersedia, film, anime,...
# 9996  [menyesal, berlanggan, vidio, pembayaran, otom...
# 9997  [tolong, apknya, update, gak, film, midnight, ...
# 9998  [nonton, premier, league, vidionya, lambat, si...
# 9999                        [bagus, aplikasinya, iklan]
#
#                                        pos_tags_content  \
# 0     [(sumpah, NN), (aplikasi, NN), (bikin, FW), (g...
# 1     [(lumayan, NN), (bagus, JJ), (tolong, VB), (pe...
# 2     [(bagus, JJ), (banget, NN), (lihat, VB), (tv, ...
# 3     [(tampilkan, VB), (liga, CD), (nntin, NN), (la...
# 4     [(kayaknya, RB), (aplikasi, VB), (oona, NN), (...
# ...                                                 ...
# 9995  [(aplikasi, NN), (film, NN), (anime, NN), (ter...
# 9996  [(menyesal, NN), (berlanggan, NN), (vidio, NN)...
# 9997  [(tolong, VB), (apknya, RB), (update, FW), (ga...
# 9998  [(nonton, FW), (premier, FW), (league, FW), (v...
# 9999      [(bagus, JJ), (aplikasinya, RB), (iklan, VB)]
#
#                                         indexed_content  \
# 0     [sumpah, aplikasi, ulang, aja, ga, dibuka, buk...
# 1     [lumayan, bagus, tolong, perbaiki, gangguan, n...
# 2     [bagus, banget, lihat, tv, dimn, bepergian, ja...
# 3     [tampilkan, nntin, tpi, mala, tdk, alasannya, ...
# 4     [kayaknya, aplikasi, oona, bagus, yg, kecewa, ...
# ...                                                 ...
# 9995  [aplikasi, film, anime, tersedia, film, anime,...
# 9996  [menyesal, berlanggan, vidio, pembayaran, otom...
# 9997                                   [tolong, apknya]
# 9998  [vidionya, lambat, situs, ilegal, official, pa...
# 9999                        [bagus, aplikasinya, iklan]
#
#                                       lemmas_to_content  \
# 0     sumpah aplikasi ulang aja ga dibuka buka muncu...
# 1     lumayan bagus tolong perbaiki gangguan nya cha...
# 2     bagus banget lihat tv dimn bepergian jarak jau...
# 3     tampilkan nntin tpi mala tdk alasannya hak cip...
# 4     kayaknya aplikasi oona bagus yg kecewa dgn apl...
# ...                                                 ...
# 9995  aplikasi film anime tersedia film anime tersed...
# 9996  menyesal berlanggan vidio pembayaran otomatis ...
# 9997                                      tolong apknya
# 9998  vidionya lambat situs ilegal official partner ...
# 9999                            bagus aplikasinya iklan
#
#                                         stemmed_content
# 0     sumpah aplikasi bikin gw kesel udah gw hapus t...
# 1     lumayan bagus tolong baik ganggu nya channel p...
# 2     bagus banget lihat tv dimn pergi jarak jauhdek...
# 3     tampil liga nntin laliga liga champion tpi mal...
# 4     kayak aplikasi oona bagus yg kecewa dgn aplika...
# ...                                                 ...
# 9995  aplikasi film anime sedia film anime sedia apl...
# 9996  sesal langgan vidio bayar otomatis potong dana...
# 9997      tolong apknya update gak film midnight runner
# 9998  nonton premier league vidionya lambat situs il...
# 9999                               bagus aplikasi iklan
#
# [10000 rows x 9 columns]

# %% [markdown]
# ## Data Splitting

# %%
from sklearn.model_selection import train_test_split

X = data_preproc['stemmed_content']
y = data_preproc['sentiment']

# %%
X
# Out:
# 0       sumpah aplikasi bikin gw kesel udah gw hapus t...
# 1       lumayan bagus tolong baik ganggu nya channel p...
# 2       bagus banget lihat tv dimn pergi jarak jauhdek...
# 3       tampil liga nntin laliga liga champion tpi mal...
# 4       kayak aplikasi oona bagus yg kecewa dgn aplika...
#                               ...
# 9995    aplikasi film anime sedia film anime sedia apl...
# 9996    sesal langgan vidio bayar otomatis potong dana...
# 9997        tolong apknya update gak film midnight runner
# 9998    nonton premier league vidionya lambat situs il...
# 9999                                 bagus aplikasi iklan
# Name: stemmed_content, Length: 10000, dtype: object

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 9995    1
# 9996    1
# 9997    1
# 9998    1
# 9999    1
# Name: sentiment, Length: 10000, dtype: int64

# %%
y.value_counts()
# Out:
# sentiment
# 1    7461
# 0    2539
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
#Split Data 70% training 30% testing
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size = 0.3,
                                                    random_state = 123,
                                                    stratify=y)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\utils\validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\utils\validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
X_train
# Out:
# 2166    bantu orang yg gx tv lihat chanel yg suka yg l...
# 6196    streaming nya si ok ga lag kecawa bgt pas stre...
# 5211    acara bola liga ingris pra laga pakai bandit b...
# 1867    kenal nama bunga kls suka sih salah vidio gk b...
# 5858    ni aplikasi latih sabar seru seru nya nonton t...
#                               ...
# 9456                     cuman fokus serial tv film jadul
# 1735    mohon maaf ksh bintang iklan mohon rang iklann...
# 2560    gimana ni udah langgan jam doang habis loading...
# 3359    gk enak nonton ikat cinta tanggal nya gk trs t...
# 2718    paksa bintang nawarin promo guna tp tunggu pro...
# Name: stemmed_content, Length: 7000, dtype: object

# %%
X_test
# Out:
# 6709    baguss tolonglahh iklan banyaksetiap seru nya ...
# 4882    premium bayar eh payah loading live nya banget...
# 7367    bandingin ama yutub platform app iklan banyakm...
# 3340    dlu sblm upgradeaplikasi bs floating hp ku dgn...
# 4983    iklan masuk tayang iklan masuk tayang skip ikl...
#                               ...
# 3626    beli paket proses nya tdk trus pake beli paket...
# 145     aja video simpan video aplikasi putar sy coba ...
# 595     asli kasih bintang gajadi salur antv admin tol...
# 8161    pilih tonton filmsport dll aplikasi vidio liha...
# 8533    udah mantaappmin tambahin film kartun anak yg ...
# Name: stemmed_content, Length: 3000, dtype: object

# %%
y_train
# Out:
# 2166    0
# 6196    1
# 5211    1
# 1867    1
# 5858    1
#        ..
# 9456    1
# 1735    1
# 2560    1
# 3359    1
# 2718    1
# Name: sentiment, Length: 7000, dtype: int64

# %%
y_test
# Out:
# 6709    1
# 4882    1
# 7367    1
# 3340    1
# 4983    1
#        ..
# 3626    0
# 145     1
# 595     1
# 8161    0
# 8533    0
# Name: sentiment, Length: 3000, dtype: int64

# %%
# Split data train menjadi train dan validation set
X_test, X_valid, y_test, y_valid = train_test_split(X_test, y_test, 
                                                    test_size=0.4, 
                                                    random_state=42,
                                                    stratify = y_test
                                                   )
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\utils\validation.py:605: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\utils\validation.py:614: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
X_test
# Out:
# 7025                 sayah udah langgan iklan tolong baik
# 149     bagus nih channel axn animax nya coming soon t...
# 7067    knp ya download magic gagal pas download yg ko...
# 3715    bagus utk nonton film chanel tv iklan lumayan ...
# 2971    aplikasi bagus tpi haya gk lengkap masak nonto...
#                               ...
# 8961    bingung beli paket platinum via indosat n goog...
# 2798    masuk homepage tulis failed to load comeback i...
# 9700    aplikasi nya gagal tampil halaman sinyal bagus...
# 1954    suka aplikasi tolong serial jodha akbar lengka...
# 6168    aplikasi sial gak andal final buka gak tonton ...
# Name: stemmed_content, Length: 1800, dtype: object

# %%
X_valid
# Out:
# 6366    bagus sih g lengkap film kamen rider black sun...
# 500     langgan premier tp tulis capai maksimal perang...
# 8740    apl nya bagus ga kendala gampang beli fitur pr...
# 1304    eheheh udah bintang tuh mueheeee aplikasi bagu...
# 2356    aplikasi oke aja thanks ya vidiocuman klo dido...
#                               ...
# 7064    min dowload film download kga download dowload...
# 1763    aps vidio bagus kekuranganyayaitu koleksi drak...
# 9620                             g nonton bola beli paket
# 2550    nonton vidiolagi seru eh iklan gitu aja iklan ...
# 6710    heran ni aplikasi pake data lot nya ampunpadah...
# Name: stemmed_content, Length: 1200, dtype: object

# %%
y_test.value_counts()
# Out:
# sentiment
# 1    1343
# 0     457
# Name: count, dtype: int64

# %%
y_valid.value_counts()
# Out:
# sentiment
# 1    895
# 0    305
# Name: count, dtype: int64

# %% [markdown]
# ## TFIDF

# %%
X_train = X_train.reset_index()
X_test  = X_test.reset_index()
X_valid = X_valid.reset_index()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import joblib
import pickle

# Inisialisasi dan fit TfidfVectorizer
def fit_tfidf_vectorizer(X_train):
    tfidf_vectorizer = TfidfVectorizer()
    tfidf_vectorizer.fit(X_train['stemmed_content'])
    
    # Simpan TfidfVectorizer
    with open('model/tfidf_vectorizer.pkl', 'wb') as f:
        pickle.dump(tfidf_vectorizer, f)
    
    return tfidf_vectorizer

# %%
# Load TfidfVectorizer dari file
def load_tfidf_vectorizer(file_path):
    with open(file_path, 'rb') as f:
        tfidf_vectorizer = pickle.load(f)
    return tfidf_vectorizer

# %%
X_train_fit = fit_tfidf_vectorizer(X_train)
X_train_fit
# Out:
# TfidfVectorizer()

# %%
# Memuat TfidfVectorizer dari file
tfidf_vectorizer = load_tfidf_vectorizer('model/tfidf_vectorizer.pkl')

# %%
# Transformasi data pelatihan
X_train_tfidf = tfidf_vectorizer.transform(X_train['stemmed_content'])
# Transformasi data uji
X_test_tfidf = tfidf_vectorizer.transform(X_test['stemmed_content'])
# Transformasi data validasi
X_valid_tfidf = tfidf_vectorizer.transform(X_valid['stemmed_content'])

# %%
X_train_tfidf
# Out:
# <7000x11664 sparse matrix of type '<class 'numpy.float64'>'
# 	with 108136 stored elements in Compressed Sparse Row format>

# %%
X_test_tfidf
# Out:
# <1800x11664 sparse matrix of type '<class 'numpy.float64'>'
# 	with 25534 stored elements in Compressed Sparse Row format>

# %%
X_valid_tfidf
# Out:
# <1200x11664 sparse matrix of type '<class 'numpy.float64'>'
# 	with 17107 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Save Data

# %%
util.pickle_dump(X_train_tfidf, config_data["train_tfidf_set_path"][0])
util.pickle_dump(y_train, config_data["train_tfidf_set_path"][1])
    
util.pickle_dump(X_valid_tfidf, config_data["valid_tfidf_set_path"][0])
util.pickle_dump(y_valid, config_data["valid_tfidf_set_path"][1])

util.pickle_dump(X_test_tfidf, config_data["test_tfidf_set_path"][0])
util.pickle_dump(y_test, config_data["test_tfidf_set_path"][1])
